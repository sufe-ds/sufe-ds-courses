# %% [markdown]
# 这堂课我们将学习如何使用Python进行面向对象式编程（Object-Oriented Programming，简称OOP）。我们将通过实现一个简单的量化交易策略，来深入理解OOP这种编程范式的强大之处。通过这堂课，你将掌握如下知识点。
#
# 1. 使用Python进行OOP的基本语法。包括类（class）、实例（instance）、属性（attribute）以及方法（method）等知识点。
# 2. 如何从OOP的角度进行思考，设计复杂问题的解决方案。
# 3. 使用Python进行OOP的高级语法。包括`__repr__`、`__call__`等特殊方法的使用，以及`@property`装饰器的使用等进阶知识点。

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %% [markdown]
# # 问题描述

# %% [markdown]
# 我们将实现一个简单的基于趋势跟随（Trend Following）的股票交易策略（Trading Strategy）。该策略通过判断一只股票的当前价格是否高于（低于）其近期的均值水平，来决定是否买入（卖出）该股票。我们将基于该策略，构造一个投资组合（Portfolio），并通过回测（backtest）该Portfolio的历史表现，来评估策略的有效性。
#
# 思考：如何拆解该问题？
#
# 1. Portfolio是由股票构成的资产集合。那么，如何存储单支股票的数据？
# 2. 基于个股数据，便可以进行模拟交易。所谓构建Portfolio，本质上是追踪一系列股票交易行为。那么，如何存储交易数据？
# 3. 基于一个Portfolio的交易数据，可以计算该Portfolio在任意时间点的持仓数据。结合个股数据，便可以计算该Portfolio在该时间点的资产价值。
# 4. 交易策略，可以抽象地理解为一个根据给定规则生成交易数据的算法。那么，该如何设计这个算法？
#
# 接下来，让我们先关注第一个问题，并学习如何基于OOP的思想来设计解决方案。

# %% [markdown]
# 不过在正式开始OOP的学习之前，让我们先来准备些股票的历史数据。

# %%
# Fetch real-world stock data
stock_symbols = ["AAPL", "MSFT", "GOOGL", "BA", "WBA", "INTC"]
start_date = "2020-01-01"
end_date = "2024-10-31"

save_path = Path('./stock_data')
save_path.mkdir(exist_ok=True)
resave = False

stock_data = {}
for symbol in stock_symbols:
    save_as = save_path/f"{symbol}.csv"
    if not save_as.is_file() or resave:
        try:
            import yfinance as yf
            stock_df = yf.download(symbol, start=start_date, end=end_date)
            stock_df = stock_df.droplevel(level='Ticker', axis=1)
            stock_df.columns.name = None
            stock_df.index.name = None
            stock_df.index = stock_df.index.tz_localize(None)
            stock_df.to_csv(save_as, index=True)
        except ImportError:
            # Install the required library
            # !pip install yfinance
            raise ImportError('The yfinance has not been imported!')
    else:
        stock_df = pd.read_csv(save_as, index_col=0, parse_dates=True)
    stock_data[symbol] = dict(zip(stock_df.index.to_pydatetime(), stock_df["Adj Close"]))

# %%
# stock_data['AAPL']

# %%
stock_df["Adj Close"]
# Out:
# 2020-01-02    53.666470
# 2020-01-03    53.013714
# 2020-01-06    52.863766
# 2020-01-07    51.981674
# 2020-01-08    52.016960
#                 ...
# 2024-10-24    22.340000
# 2024-10-25    22.680000
# 2024-10-28    22.920000
# 2024-10-29    22.900000
# 2024-10-30    22.299999
# Name: Adj Close, Length: 1216, dtype: float64

# %%
for k, v in stock_data['AAPL'].items():
    print(k, v, type(k), type(v), sep=' | ')
    break
# Out:
# 2020-01-02 00:00:00 | 72.87610626220703 | <class 'datetime.datetime'> | <class 'float'>

# %%
1.0+2.0
# Out:
# 3.0

# %% [markdown]
# $\Delta$

# %%
datetime(2023, 12, 1, 0, 0) - timedelta(days=2)
# Out:
# datetime.datetime(2023, 11, 29, 0, 0)

# %%
# stock_data['AAPL']

# %% [markdown]
# 如何方便的查看字典的前n个条目（entry）？

# %%
for i, (k, v) in enumerate(stock_data['AAPL'].items()):
    print(k, v, type(k), type(v), sep=' | ')
    if i >= 5:
        break
# Out:
# 2020-01-02 00:00:00 | 72.87610626220703 | <class 'datetime.datetime'> | <class 'float'>
# 2020-01-03 00:00:00 | 72.16758728027344 | <class 'datetime.datetime'> | <class 'float'>
# 2020-01-06 00:00:00 | 72.74266052246094 | <class 'datetime.datetime'> | <class 'float'>
# 2020-01-07 00:00:00 | 72.40054321289062 | <class 'datetime.datetime'> | <class 'float'>
# 2020-01-08 00:00:00 | 73.5652084350586 | <class 'datetime.datetime'> | <class 'float'>
# 2020-01-09 00:00:00 | 75.12776947021484 | <class 'datetime.datetime'> | <class 'float'>

# %% [markdown]
# 我们将每支股票的数据，存储为一个字典。该字典的每个条目中，键（key）是一个时间日期，表示一个交易日；值（value）是该股票在该交易日的收盘价格，可以用来近似交易策略中可以执行的买卖价格。

# %%
k
# Out:
# datetime.datetime(2020, 1, 9, 0, 0)

# %% [markdown]
# 注意到，每个key的类型为`datetime.datetime`。用OOP的术语来说，每个key是`datetime.datetime`类的一个实例（instance）。通过这个例子，你可以总结出类和实例的一般定义么？
#
# 注意，在OOP的相关资料中，会频繁使用对象（object）这一术语。大部分情况下，可以将object理解为instance的同义词。

# %% [markdown]
# # 定义`Stock`类

# %% [markdown]
# 考虑到不同的股票都有相同的数据字段，我们可以定义`Stock`类，来一般性地描述一支股票应该包含的数据以及支持的操作。下面的代码声明了`Stock`类，请阅读该代码来理解以下知识点。
#
# 1. 如何声明一个类？
# 2. 如何定义一个类的实例化方法，即`__init__`方法？
# 3. 什么是以及如何定义实例属性（attribute）和实例方法（method）？
# 4. 如何理解实例方法中的`self`参数？

# %%
# Define the Stock class
class Stock:
    
    def __init__(self, name, ticker, historical_prices):
        # ticker might change over time, `name` is intended to hold the permenant name of a stock
        self.name = name
        self.ticker = ticker
        self.historical_prices = historical_prices  # Dictionary of {date: price}
        self.trading_dates = sorted(historical_prices.keys())  # Only store valid trading dates
    
    def get_price(self, date):
        return self.historical_prices.get(date, None)
    
    def __getitem__(self, idx):
        return self.get_price(self.trading_dates[idx])

# %%
symbol = 'AAPL'
stock_aapl = Stock(symbol, symbol, stock_data[symbol])

# %%
stock_aapl.trading_dates[1]
# Out:
# datetime.datetime(2020, 1, 3, 0, 0)

# %%
stock_aapl[1]
# Out:
# 72.16758728027344

# %%
stock_aapl.get_price(datetime(2020, 1, 22, 0, 0))
# Out:
# 77.08585357666016

# %%
stock_aapl.historical_prices.get(datetime(2020, 1, 22, 0, 0), None)
# Out:
# 77.08585357666016

# %%
stock_aapl

# %%
# stock_aapl.trading_dates

# %%
stock_aapl.historical_prices[stock_aapl.trading_dates[0]]
# Out:
# 72.87610626220703

# %% [markdown]
# 按照如下方案进一步完善`Stock`类。
#
#
# 1. 定义实例方法`__getitem__`，让查询股票历史价格变得更加方便。
# 2. 定义实例方法`__repr__`，更直观地展示`Stock`对象的内容。
# 3. 定义实例方法`get_trading_dates_in_range`，返回一个给定日期范围内的交易日。
# 4. 定义类属性`stock_data`和类方法`from_ticker`，让根据股票ticker实例化`Stock`对象更加方便。

# %% [markdown]
# 请阅读下方代码，学习并掌握上述4个知识点。

# %%
# Define the Stock class
class Stock:
    
    # make `stock_data` a private attribute
    _stock_data = stock_data
    # alternatively, make `stock_data` a public attribute
#     _stock_data = stock_data
    
    def __init__(self, name, ticker, historical_prices):
        # ticker might change over time, `name` is intended to hold the permenant name of a stock
        self.name = name
        self.ticker = ticker
        self.historical_prices = historical_prices  # Dictionary of {date: price}
        self.trading_dates = sorted(historical_prices.keys())  # Only store valid trading dates
    
    
    def __getitem__(self, idx):
        if isinstance(idx, int):
            return self.historical_prices[self.trading_dates[idx]]
        elif isinstance(idx, datetime):
            return self.get_price(idx)
        else:
            raise NotImplementedError
            
    def __repr__(self):
        k0 = self.trading_dates[0]
        v0 = self.historical_prices[k0]
        k0_str = k0.strftime('%Y-%m-%d')
        k1 = self.trading_dates[-1]
        v1 = self.historical_prices[k1]
        k1_str = k1.strftime('%Y-%m-%d')
        return f"name:{self.name}|ticker:{self.ticker}|data:{{{k0_str}:{v0:.2f}, ..., {k1_str}:{v1:.2f}}}"
            
    def get_price(self, date):
        return self.historical_prices.get(date, None)

    def get_trading_dates_in_range(self, start_date, end_date):
        # Filter trading dates within the specified date range
        return [date for date in self.trading_dates if start_date <= date <= end_date]
    
    @classmethod
    def from_ticker(cls, symbol):
        return cls(symbol, symbol, cls._stock_data[symbol])

# %%
for date in stock_aapl.trading_dates:
    print(date)
    break
# Out:
# 2020-01-02 00:00:00

# %% [markdown]
# 测试功能

# %%
symbol = 'AAPL'
stock_aapl = Stock(symbol, symbol, stock_data[symbol])
Stock(symbol, symbol, Stock._stock_data[symbol])
# Out:
# name:AAPL|ticker:AAPL|data:{2020-01-02:72.88, ..., 2024-10-30:230.10}

# %%
stock_aapl[0]
# Out:
# 72.87610626220703

# %%
stock_aapl[stock_aapl.trading_dates[0]]
# Out:
# 72.87610626220703

# %%
stock_aapl
# Out:
# name:AAPL|ticker:AAPL|data:{2020-01-02:72.88, ..., 2024-10-30:230.10}

# %%
k0 = stock_aapl.trading_dates[0]
v0 = stock_aapl.historical_prices[k0]
# k0_str = k0.strftime('%Y-%m-%d')

# %%
k0.strftime('%Y%m%d')
# Out:
# '20200102'

# %%
stock_aapl.get_trading_dates_in_range(stock_aapl.trading_dates[-3], stock_aapl.trading_dates[-1])
# Out:
# [datetime.datetime(2024, 10, 28, 0, 0),
#  datetime.datetime(2024, 10, 29, 0, 0),
#  datetime.datetime(2024, 10, 30, 0, 0)]

# %%
Stock('AAPL', 'AAPL', stock_data['AAPL'])
Stock('MSFT', 'MSFT', stock_data['MSFT'])
# Out:
# name:MSFT|ticker:MSFT|data:{2020-01-02:153.94, ..., 2024-10-30:432.53}

# %%
stock_aapl = Stock.from_ticker('AAPL')

Stock('AAPL', 'AAPL', Stock._stock_data['AAPL'])

stock_aapl
# Out:
# name:AAPL|ticker:AAPL|data:{2020-01-02:72.88, ..., 2024-10-30:230.10}

# %%
Stock._stock_data
# Out:
# {'AAPL': {datetime.datetime(2020, 1, 2, 0, 0): 72.87610626220703,
#   datetime.datetime(2020, 1, 3, 0, 0): 72.16758728027344,
#   datetime.datetime(2020, 1, 6, 0, 0): 72.74266052246094,
#   datetime.datetime(2020, 1, 7, 0, 0): 72.40054321289062,
#   datetime.datetime(2020, 1, 8, 0, 0): 73.5652084350586,
#   datetime.datetime(2020, 1, 9, 0, 0): 75.12776947021484,
#   datetime.datetime(2020, 1, 10, 0, 0): 75.2976303100586,
#   datetime.datetime(2020, 1, 13, 0, 0): 76.90630340576172,
#   datetime.datetime(2020, 1, 14, 0, 0): 75.8678207397461,
#   datetime.datetime(2020, 1, 15, 0, 0): 75.54267883300781,
#   datetime.datetime(2020, 1, 16, 0, 0): 76.48898315429688,
#   datetime.datetime(2020, 1, 17, 0, 0): 77.3357925415039,
#   datetime.datetime(2020, 1, 21, 0, 0): 76.81167602539062,
#   datetime.datetime(2020, 1, 22, 0, 0): 77.08585357666016,
#   datetime.datetime(2020, 1, 23, 0, 0): 77.45709228515625,
#   datetime.datetime(2020, 1, 24, 0, 0): 77.23385620117188,
#   datetime.datetime(2020, 1, 27, 0, 0): 74.96278381347656,
#   datetime.datetime(2020, 1, 28, 0, 0): 77.08345031738281,
#   datetime.datetime(2020, 1, 29, 0, 0): 78.69697570800781,
#   datetime.datetime(2020, 1, 30, 0, 0): 78.58293914794922,
#   datetime.datetime(2020, 1, 31, 0, 0): 75.09867858886719,
#   datetime.datetime(2020, 2, 3, 0, 0): 74.8924331665039,
#   datetime.datetime(2020, 2, 4, 0, 0): 77.36490631103516,
#   datetime.datetime(2020, 2, 5, 0, 0): 77.99575805664062,
#   datetime.datetime(2020, 2, 6, 0, 0): 78.90806579589844,
#   datetime.datetime(2020, 2, 7, 0, 0): 77.83551788330078,
#   datetime.datetime(2020, 2, 10, 0, 0): 78.2051773071289,
#   datetime.datetime(2020, 2, 11, 0, 0): 77.73334503173828,
#   datetime.datetime(2020, 2, 12, 0, 0): 79.57933807373047,
#   datetime.datetime(2020, 2, 13, 0, 0): 79.01265716552734,
#   datetime.datetime(2020, 2, 14, 0, 0): 79.03211975097656,
#   datetime.datetime(2020, 2, 18, 0, 0): 77.58500671386719,
#   datetime.datetime(2020, 2, 19, 0, 0): 78.7086410522461,
#   datetime.datetime(2020, 2, 20, 0, 0): 77.90115356445312,
#   datetime.datetime(2020, 2, 21, 0, 0): 76.13787078857422,
#   datetime.datetime(2020, 2, 24, 0, 0): 72.52127075195312,
#   datetime.datetime(2020, 2, 25, 0, 0): 70.06484985351562,
#   datetime.datetime(2020, 2, 26, 0, 0): 71.17632293701172,
#   datetime.datetime(2020, 2, 27, 0, 0): 66.52365112304688,
#   datetime.datetime(2020, 2, 28, 0, 0): 66.48473358154297,
#   datetime.datetime(2020, 3, 2, 0, 0): 72.67450714111328,
#   datetime.datetime(2020, 3, 3, 0, 0): 70.36643981933594,
#   datetime.datetime(2020, 3, 4, 0, 0): 73.63034057617188,
#   datetime.datetime(2020, 3, 5, 0, 0): 71.24199676513672,
#   datetime.datetime(2020, 3, 6, 0, 0): 70.29589080810547,
#   datetime.datetime(2020, 3, 9, 0, 0): 64.73603820800781,
#   datetime.datetime(2020, 3, 10, 0, 0): 69.39840698242188,
#   datetime.datetime(2020, 3, 11, 0, 0): 66.98818969726562,
#   datetime.datetime(2020, 3, 12, 0, 0): 60.37278747558594,
#   datetime.datetime(2020, 3, 13, 0, 0): 67.6059341430664,
#   datetime.datetime(2020, 3, 16, 0, 0): 58.908653259277344,
#   datetime.datetime(2020, 3, 17, 0, 0): 61.49887466430664,
#   datetime.datetime(2020, 3, 18, 0, 0): 59.99338912963867,
#   datetime.datetime(2020, 3, 19, 0, 0): 59.53371047973633,
#   datetime.datetime(2020, 3, 20, 0, 0): 55.75417709350586,
#   datetime.datetime(2020, 3, 23, 0, 0): 54.56972503662109,
#   datetime.datetime(2020, 3, 24, 0, 0): 60.044464111328125,
#   datetime.datetime(2020, 3, 25, 0, 0): 59.713680267333984,
#   datetime.datetime(2020, 3, 26, 0, 0): 62.85600662231445,
#   datetime.datetime(2020, 3, 27, 0, 0): 60.25362396240234,
#   datetime.datetime(2020, 3, 30, 0, 0): 61.973140716552734,
#   datetime.datetime(2020, 3, 31, 0, 0): 61.8466682434082,
#   datetime.datetime(2020, 4, 1, 0, 0): 58.59248352050781,
#   datetime.datetime(2020, 4, 2, 0, 0): 59.5701904296875,
#   datetime.datetime(2020, 4, 3, 0, 0): 58.71408462524414,
#   datetime.datetime(2020, 4, 6, 0, 0): 63.83615112304688,
#   datetime.datetime(2020, 4, 7, 0, 0): 63.09677505493164,
#   datetime.datetime(2020, 4, 8, 0, 0): 64.71172332763672,
#   datetime.datetime(2020, 4, 9, 0, 0): 65.17870330810547,
#   datetime.datetime(2020, 4, 13, 0, 0): 66.45799255371094,
#   datetime.datetime(2020, 4, 14, 0, 0): 69.81431579589844,
#   datetime.datetime(2020, 4, 15, 0, 0): 69.1771011352539,
#   datetime.datetime(2020, 4, 16, 0, 0): 69.7267837524414,
#   datetime.datetime(2020, 4, 17, 0, 0): 68.78064727783203,
#   datetime.datetime(2020, 4, 20, 0, 0): 67.3530044555664,
#   datetime.datetime(2020, 4, 21, 0, 0): 65.27108764648438,
#   datetime.datetime(2020, 4, 22, 0, 0): 67.1511459350586,
#   datetime.datetime(2020, 4, 23, 0, 0): 66.89091491699219,
#   datetime.datetime(2020, 4, 24, 0, 0): 68.82201385498047,
#   datetime.datetime(2020, 4, 27, 0, 0): 68.87067413330078,
#   datetime.datetime(2020, 4, 28, 0, 0): 67.7542953491211,
#   datetime.datetime(2020, 4, 29, 0, 0): 69.97974395751953,
#   datetime.datetime(2020, 4, 30, 0, 0): 71.45602416992188,
#   datetime.datetime(2020, 5, 1, 0, 0): 70.3056411743164,
#   datetime.datetime(2020, 5, 4, 0, 0): 71.30035400390625,
#   datetime.datetime(2020, 5, 5, 0, 0): 72.3705062866211,
#   datetime.datetime(2020, 5, 6, 0, 0): 73.1171646118164,
#   datetime.datetime(2020, 5, 7, 0, 0): 73.8735580444336,
#   datetime.datetime(2020, 5, 8, 0, 0): 75.63188171386719,
#   datetime.datetime(2020, 5, 11, 0, 0): 76.82196044921875,
#   datetime.datetime(2020, 5, 12, 0, 0): 75.94403839111328,
#   datetime.datetime(2020, 5, 13, 0, 0): 75.02706909179688,
#   datetime.datetime(2020, 5, 14, 0, 0): 75.48799896240234,
#   datetime.datetime(2020, 5, 15, 0, 0): 75.04170227050781,
#   datetime.datetime(2020, 5, 18, 0, 0): 76.80976867675781,
#   datetime.datetime(2020, 5, 19, 0, 0): 76.36592102050781,
#   datetime.datetime(2020, 5, 20, 0, 0): 77.85111236572266,
#   datetime.datetime(2020, 5, 21, 0, 0): 77.27069091796875,
#   datetime.datetime(2020, 5, 22, 0, 0): 77.7681884765625,
#   datetime.datetime(2020, 5, 26, 0, 0): 77.24143981933594,
#   datetime.datetime(2020, 5, 27, 0, 0): 77.57797241210938,
#   datetime.datetime(2020, 5, 28, 0, 0): 77.61211395263672,
#   datetime.datetime(2020, 5, 29, 0, 0): 77.5364990234375,
#   datetime.datetime(2020, 6, 1, 0, 0): 78.49004364013672,
#   datetime.datetime(2020, 6, 2, 0, 0): 78.85340881347656,
#   datetime.datetime(2020, 6, 3, 0, 0): 79.28751373291016,
#   datetime.datetime(2020, 6, 4, 0, 0): 78.60466003417969,
#   datetime.datetime(2020, 6, 5, 0, 0): 80.8434066772461,
#   datetime.datetime(2020, 6, 8, 0, 0): 81.32138061523438,
#   datetime.datetime(2020, 6, 9, 0, 0): 83.88935852050781,
#   datetime.datetime(2020, 6, 10, 0, 0): 86.0476303100586,
#   datetime.datetime(2020, 6, 11, 0, 0): 81.91645050048828,
#   datetime.datetime(2020, 6, 12, 0, 0): 82.62366485595703,
#   datetime.datetime(2020, 6, 15, 0, 0): 83.64547729492188,
#   datetime.datetime(2020, 6, 16, 0, 0): 85.86227416992188,
#   datetime.datetime(2020, 6, 17, 0, 0): 85.7427749633789,
#   datetime.datetime(2020, 6, 18, 0, 0): 85.77693939208984,
#   datetime.datetime(2020, 6, 19, 0, 0): 85.2867202758789,
#   datetime.datetime(2020, 6, 22, 0, 0): 87.5181655883789,
#   datetime.datetime(2020, 6, 23, 0, 0): 89.38621520996094,
#   datetime.datetime(2020, 6, 24, 0, 0): 87.8083724975586,
#   datetime.datetime(2020, 6, 25, 0, 0): 88.97407531738281,
#   datetime.datetime(2020, 6, 26, 0, 0): 86.24028778076172,
#   datetime.datetime(2020, 6, 29, 0, 0): 88.22782135009766,
#   datetime.datetime(2020, 6, 30, 0, 0): 88.96432495117188,
#   datetime.datetime(2020, 7, 1, 0, 0): 88.79605102539062,
#   datetime.datetime(2020, 7, 2, 0, 0): 88.79605102539062,
#   datetime.datetime(2020, 7, 6, 0, 0): 91.17137145996094,
#   datetime.datetime(2020, 7, 7, 0, 0): 90.88846588134766,
#   datetime.datetime(2020, 7, 8, 0, 0): 93.00527954101562,
#   datetime.datetime(2020, 7, 9, 0, 0): 93.4052276611328,
#   datetime.datetime(2020, 7, 10, 0, 0): 93.56863403320312,
#   datetime.datetime(2020, 7, 13, 0, 0): 93.136962890625,
#   datetime.datetime(2020, 7, 14, 0, 0): 94.67822265625,
#   datetime.datetime(2020, 7, 15, 0, 0): 95.32938385009766,
#   datetime.datetime(2020, 7, 16, 0, 0): 94.15635681152344,
#   datetime.datetime(2020, 7, 17, 0, 0): 93.96613311767578,
#   datetime.datetime(2020, 7, 20, 0, 0): 95.94638061523438,
#   datetime.datetime(2020, 7, 21, 0, 0): 94.62215423583984,
#   datetime.datetime(2020, 7, 22, 0, 0): 94.88795471191406,
#   datetime.datetime(2020, 7, 23, 0, 0): 90.56900787353516,
#   datetime.datetime(2020, 7, 24, 0, 0): 90.34463500976562,
#   datetime.datetime(2020, 7, 27, 0, 0): 92.48583221435548,
#   datetime.datetime(2020, 7, 28, 0, 0): 90.9665069580078,
#   datetime.datetime(2020, 7, 29, 0, 0): 92.71018981933594,
#   datetime.datetime(2020, 7, 30, 0, 0): 93.8319854736328,
#   datetime.datetime(2020, 7, 31, 0, 0): 103.65515899658205,
#   datetime.datetime(2020, 8, 3, 0, 0): 106.26700592041016,
#   datetime.datetime(2020, 8, 4, 0, 0): 106.97666931152344,
#   datetime.datetime(2020, 8, 5, 0, 0): 107.36443328857422,
#   datetime.datetime(2020, 8, 6, 0, 0): 111.11031341552734,
#   datetime.datetime(2020, 8, 7, 0, 0): 108.58413696289062,
#   datetime.datetime(2020, 8, 10, 0, 0): 110.1623764038086,
#   datetime.datetime(2020, 8, 11, 0, 0): 106.88616180419922,
#   datetime.datetime(2020, 8, 12, 0, 0): 110.4384307861328,
#   datetime.datetime(2020, 8, 13, 0, 0): 112.39293670654295,
#   datetime.datetime(2020, 8, 14, 0, 0): 112.29276275634766,
#   datetime.datetime(2020, 8, 17, 0, 0): 111.99958038330078,
#   datetime.datetime(2020, 8, 18, 0, 0): 112.932861328125,
#   datetime.datetime(2020, 8, 19, 0, 0): 113.07454681396484,
#   datetime.datetime(2020, 8, 20, 0, 0): 115.58363342285156,
#   datetime.datetime(2020, 8, 21, 0, 0): 121.53994750976562,
#   datetime.datetime(2020, 8, 24, 0, 0): 122.99359130859376,
#   datetime.datetime(2020, 8, 25, 0, 0): 121.98458862304688,
#   datetime.datetime(2020, 8, 26, 0, 0): 123.6434555053711,
#   datetime.datetime(2020, 8, 27, 0, 0): 122.16536712646484,
#   datetime.datetime(2020, 8, 28, 0, 0): 121.9674835205078,
#   datetime.datetime(2020, 8, 31, 0, 0): 126.10366821289062,
#   datetime.datetime(2020, 9, 1, 0, 0): 131.126708984375,
#   datetime.datetime(2020, 9, 2, 0, 0): 128.40997314453125,
#   datetime.datetime(2020, 9, 3, 0, 0): 118.12935638427734,
#   datetime.datetime(2020, 9, 4, 0, 0): 118.2075424194336,
#   datetime.datetime(2020, 9, 8, 0, 0): 110.25276184082033,
#   datetime.datetime(2020, 9, 9, 0, 0): 114.65036010742188,
#   datetime.datetime(2020, 9, 10, 0, 0): 110.90752410888672,
#   datetime.datetime(2020, 9, 11, 0, 0): 109.45142364501952,
#   datetime.datetime(2020, 9, 14, 0, 0): 112.73497009277344,
#   datetime.datetime(2020, 9, 15, 0, 0): 112.91088104248048,
#   datetime.datetime(2020, 9, 16, 0, 0): 109.57846069335938,
#   datetime.datetime(2020, 9, 17, 0, 0): 107.82919311523438,
#   datetime.datetime(2020, 9, 18, 0, 0): 104.4088363647461,
#   datetime.datetime(2020, 9, 21, 0, 0): 107.5750961303711,
#   datetime.datetime(2020, 9, 22, 0, 0): 109.26575469970705,
#   datetime.datetime(2020, 9, 23, 0, 0): 104.68247985839844,
#   datetime.datetime(2020, 9, 24, 0, 0): 105.7574462890625,
#   datetime.datetime(2020, 9, 25, 0, 0): 109.7250518798828,
#   datetime.datetime(2020, 9, 28, 0, 0): 112.34407043457033,
#   datetime.datetime(2020, 9, 29, 0, 0): 111.49384307861328,
#   datetime.datetime(2020, 9, 30, 0, 0): 113.17472076416016,
#   datetime.datetime(2020, 10, 1, 0, 0): 114.1324234008789,
#   datetime.datetime(2020, 10, 2, 0, 0): 110.4482192993164,
#   datetime.datetime(2020, 10, 5, 0, 0): 113.8490219116211,
#   datetime.datetime(2020, 10, 6, 0, 0): 110.58501434326172,
#   datetime.datetime(2020, 10, 7, 0, 0): 112.46134185791016,
#   datetime.datetime(2020, 10, 8, 0, 0): 112.35382843017578,
#   datetime.datetime(2020, 10, 9, 0, 0): 114.3083267211914,
#   datetime.datetime(2020, 10, 12, 0, 0): 121.56925201416016,
#   datetime.datetime(2020, 10, 13, 0, 0): 118.34436798095705,
#   datetime.datetime(2020, 10, 14, 0, 0): 118.43230438232422,
#   datetime.datetime(2020, 10, 15, 0, 0): 117.96321105957033,
#   datetime.datetime(2020, 10, 16, 0, 0): 116.31169128417967,
#   datetime.datetime(2020, 10, 19, 0, 0): 113.3408660888672,
#   datetime.datetime(2020, 10, 20, 0, 0): 114.83604431152344,
#   datetime.datetime(2020, 10, 21, 0, 0): 114.21060180664062,
#   datetime.datetime(2020, 10, 22, 0, 0): 113.11609649658205,
#   datetime.datetime(2020, 10, 23, 0, 0): 112.42224884033205,
#   datetime.datetime(2020, 10, 26, 0, 0): 112.43201446533205,
#   datetime.datetime(2020, 10, 27, 0, 0): 113.94673919677734,
#   datetime.datetime(2020, 10, 28, 0, 0): 108.66960906982422,
#   datetime.datetime(2020, 10, 29, 0, 0): 112.69586181640624,
#   datetime.datetime(2020, 10, 30, 0, 0): 106.38286590576172,
#   datetime.datetime(2020, 11, 2, 0, 0): 106.294921875,
#   datetime.datetime(2020, 11, 3, 0, 0): 107.92692565917967,
#   datetime.datetime(2020, 11, 4, 0, 0): 112.33428192138672,
#   datetime.datetime(2020, 11, 5, 0, 0): 116.32144927978516,
#   datetime.datetime(2020, 11, 6, 0, 0): 116.18929290771484,
#   datetime.datetime(2020, 11, 9, 0, 0): 113.86923217773438,
#   datetime.datetime(2020, 11, 10, 0, 0): 113.526611328125,
#   datetime.datetime(2020, 11, 11, 0, 0): 116.97244262695312,
#   datetime.datetime(2020, 11, 12, 0, 0): 116.6983413696289,
#   datetime.datetime(2020, 11, 13, 0, 0): 116.74728393554688,
#   datetime.datetime(2020, 11, 16, 0, 0): 117.76538848876952,
#   datetime.datetime(2020, 11, 17, 0, 0): 116.87454223632812,
#   datetime.datetime(2020, 11, 18, 0, 0): 115.54320526123048,
#   datetime.datetime(2020, 11, 19, 0, 0): 116.14035034179688,
#   datetime.datetime(2020, 11, 20, 0, 0): 114.86775207519533,
#   datetime.datetime(2020, 11, 23, 0, 0): 111.4512710571289,
#   datetime.datetime(2020, 11, 24, 0, 0): 112.74346160888672,
#   datetime.datetime(2020, 11, 25, 0, 0): 113.58534240722656,
#   datetime.datetime(2020, 11, 27, 0, 0): 114.13352966308594,
#   datetime.datetime(2020, 11, 30, 0, 0): 116.54171752929688,
#   datetime.datetime(2020, 12, 1, 0, 0): 120.1343994140625,
#   datetime.datetime(2020, 12, 2, 0, 0): 120.48680877685548,
#   datetime.datetime(2020, 12, 3, 0, 0): 120.3497543334961,
#   datetime.datetime(2020, 12, 4, 0, 0): 119.67428588867188,
#   datetime.datetime(2020, 12, 7, 0, 0): 121.14268493652344,
#   datetime.datetime(2020, 12, 8, 0, 0): 121.75940704345705,
#   datetime.datetime(2020, 12, 9, 0, 0): 119.21419525146484,
#   datetime.datetime(2020, 12, 10, 0, 0): 120.6434326171875,
#   datetime.datetime(2020, 12, 11, 0, 0): 119.83092498779295,
#   datetime.datetime(2020, 12, 14, 0, 0): 119.21419525146484,
#   datetime.datetime(2020, 12, 15, 0, 0): 125.18566131591795,
#   datetime.datetime(2020, 12, 16, 0, 0): 125.11715698242188,
#   datetime.datetime(2020, 12, 17, 0, 0): 125.98841857910156,
#   datetime.datetime(2020, 12, 18, 0, 0): 123.99138641357422,
#   datetime.datetime(2020, 12, 21, 0, 0): 125.5282974243164,
#   datetime.datetime(2020, 12, 22, 0, 0): 129.10142517089844,
#   datetime.datetime(2020, 12, 23, 0, 0): 128.2008056640625,
#   datetime.datetime(2020, 12, 24, 0, 0): 129.18951416015625,
#   datetime.datetime(2020, 12, 28, 0, 0): 133.81002807617188,
#   datetime.datetime(2020, 12, 29, 0, 0): 132.0283966064453,
#   datetime.datetime(2020, 12, 30, 0, 0): 130.90264892578125,
#   datetime.datetime(2020, 12, 31, 0, 0): 129.8943328857422,
#   datetime.datetime(2021, 1, 4, 0, 0): 126.68344116210938,
#   datetime.datetime(2021, 1, 5, 0, 0): 128.2497100830078,
#   datetime.datetime(2021, 1, 6, 0, 0): 123.93264770507812,
#   datetime.datetime(2021, 1, 7, 0, 0): 128.16165161132812,
#   datetime.datetime(2021, 1, 8, 0, 0): 129.26780700683594,
#   datetime.datetime(2021, 1, 11, 0, 0): 126.26248931884766,
#   datetime.datetime(2021, 1, 12, 0, 0): 126.08629608154295,
#   datetime.datetime(2021, 1, 13, 0, 0): 128.1322784423828,
#   datetime.datetime(2021, 1, 14, 0, 0): 126.19397735595705,
#   datetime.datetime(2021, 1, 15, 0, 0): 124.46125793457033,
#   datetime.datetime(2021, 1, 19, 0, 0): 125.13673400878906,
#   datetime.datetime(2021, 1, 20, 0, 0): 129.24822998046875,
#   datetime.datetime(2021, 1, 21, 0, 0): 133.9862823486328,
#   datetime.datetime(2021, 1, 22, 0, 0): 136.1399383544922,
#   datetime.datetime(2021, 1, 25, 0, 0): 139.90879821777344,
#   datetime.datetime(2021, 1, 26, 0, 0): 140.14373779296875,
#   datetime.datetime(2021, 1, 27, 0, 0): 139.06687927246094,
#   datetime.datetime(2021, 1, 28, 0, 0): 134.2016143798828,
#   datetime.datetime(2021, 1, 29, 0, 0): 129.17971801757812,
#   datetime.datetime(2021, 2, 1, 0, 0): 131.31378173828125,
#   datetime.datetime(2021, 2, 2, 0, 0): 132.1458740234375,
#   datetime.datetime(2021, 2, 3, 0, 0): 131.11801147460938,
#   datetime.datetime(2021, 2, 4, 0, 0): 134.4953155517578,
#   datetime.datetime(2021, 2, 5, 0, 0): 134.07864379882812,
#   datetime.datetime(2021, 2, 8, 0, 0): 134.22569274902344,
#   datetime.datetime(2021, 2, 9, 0, 0): 133.3433074951172,
#   datetime.datetime(2021, 2, 10, 0, 0): 132.73548889160156,
#   datetime.datetime(2021, 2, 11, 0, 0): 132.48062133789062,
#   datetime.datetime(2021, 2, 12, 0, 0): 132.71588134765625,
#   datetime.datetime(2021, 2, 16, 0, 0): 130.57861328125,
#   datetime.datetime(2021, 2, 17, 0, 0): 128.2747039794922,
#   datetime.datetime(2021, 2, 18, 0, 0): 127.16686248779295,
#   datetime.datetime(2021, 2, 19, 0, 0): 127.32372283935548,
#   datetime.datetime(2021, 2, 22, 0, 0): 123.52960968017578,
#   datetime.datetime(2021, 2, 23, 0, 0): 123.39234924316406,
#   datetime.datetime(2021, 2, 24, 0, 0): 122.89234924316406,
#   datetime.datetime(2021, 2, 25, 0, 0): 118.61783599853516,
#   datetime.datetime(2021, 2, 26, 0, 0): 118.8825454711914,
#   datetime.datetime(2021, 3, 1, 0, 0): 125.28451538085938,
#   datetime.datetime(2021, 3, 2, 0, 0): 122.6668472290039,
#   datetime.datetime(2021, 3, 3, 0, 0): 119.6668472290039,
#   datetime.datetime(2021, 3, 4, 0, 0): 117.7746810913086,
#   datetime.datetime(2021, 3, 5, 0, 0): 119.0394058227539,
#   datetime.datetime(2021, 3, 8, 0, 0): 114.07860565185548,
#   datetime.datetime(2021, 3, 9, 0, 0): 118.7158660888672,
#   datetime.datetime(2021, 3, 10, 0, 0): 117.62762451171876,
#   datetime.datetime(2021, 3, 11, 0, 0): 119.56881713867188,
#   datetime.datetime(2021, 3, 12, 0, 0): 118.65705871582033,
#   datetime.datetime(2021, 3, 15, 0, 0): 121.55902099609376,
#   datetime.datetime(2021, 3, 16, 0, 0): 123.10802459716795,
#   datetime.datetime(2021, 3, 17, 0, 0): 122.31391143798828,
#   datetime.datetime(2021, 3, 18, 0, 0): 118.16685485839844,
#   datetime.datetime(2021, 3, 19, 0, 0): 117.63743591308594,
#   datetime.datetime(2021, 3, 22, 0, 0): 120.97077941894533,
#   datetime.datetime(2021, 3, 23, 0, 0): 120.13743591308594,
#   datetime.datetime(2021, 3, 24, 0, 0): 117.73546600341795,
#   datetime.datetime(2021, 3, 25, 0, 0): 118.22566986083984,
#   datetime.datetime(2021, 3, 26, 0, 0): 118.83350372314452,
#   datetime.datetime(2021, 3, 29, 0, 0): 119.00997924804688,
#   datetime.datetime(2021, 3, 30, 0, 0): 117.54920196533205,
#   datetime.datetime(2021, 3, 31, 0, 0): 119.7550811767578,
#   datetime.datetime(2021, 4, 1, 0, 0): 120.5884246826172,
#   datetime.datetime(2021, 4, 5, 0, 0): 123.43154907226562,
#   datetime.datetime(2021, 4, 6, 0, 0): 123.73548889160156,
#   datetime.datetime(2021, 4, 7, 0, 0): 125.3923568725586,
#   datetime.datetime(2021, 4, 8, 0, 0): 127.80413055419922,
#   datetime.datetime(2021, 4, 9, 0, 0): 130.39236450195312,
#   datetime.datetime(2021, 4, 12, 0, 0): 128.6668701171875,
#   datetime.datetime(2021, 4, 13, 0, 0): 131.7943115234375,
#   datetime.datetime(2021, 4, 14, 0, 0): 129.44137573242188,
#   datetime.datetime(2021, 4, 15, 0, 0): 131.86294555664062,
#   datetime.datetime(2021, 4, 16, 0, 0): 131.5296173095703,
#   datetime.datetime(2021, 4, 19, 0, 0): 132.19627380371094,
#   datetime.datetime(2021, 4, 20, 0, 0): 130.50021362304688,
#   datetime.datetime(2021, 4, 21, 0, 0): 130.88258361816406,
#   datetime.datetime(2021, 4, 22, 0, 0): 129.35317993164062,
#   datetime.datetime(2021, 4, 23, 0, 0): 131.68646240234375,
#   datetime.datetime(2021, 4, 26, 0, 0): 132.07864379882812,
#   datetime.datetime(2021, 4, 27, 0, 0): 131.75509643554688,
#   datetime.datetime(2021, 4, 28, 0, 0): 130.9609832763672,
#   datetime.datetime(2021, 4, 29, 0, 0): 130.86293029785156,
#   datetime.datetime(2021, 4, 30, 0, 0): 128.88253784179688,
#   datetime.datetime(2021, 5, 3, 0, 0): 129.94137573242188,
#   datetime.datetime(2021, 5, 4, 0, 0): 125.34333038330078,
#   datetime.datetime(2021, 5, 5, 0, 0): 125.58844757080078,
#   datetime.datetime(2021, 5, 6, 0, 0): 127.1962890625,
#   datetime.datetime(2021, 5, 7, 0, 0): 127.87390899658205,
#   datetime.datetime(2021, 5, 10, 0, 0): 124.57416534423828,
#   datetime.datetime(2021, 5, 11, 0, 0): 123.65103149414062,
#   datetime.datetime(2021, 5, 12, 0, 0): 120.56737518310548,
#   datetime.datetime(2021, 5, 13, 0, 0): 122.7279052734375,
#   datetime.datetime(2021, 5, 14, 0, 0): 125.16339111328124,
#   datetime.datetime(2021, 5, 17, 0, 0): 124.0045928955078,
#   datetime.datetime(2021, 5, 18, 0, 0): 122.61006927490234,
#   datetime.datetime(2021, 5, 19, 0, 0): 122.45293426513672,
#   datetime.datetime(2021, 5, 20, 0, 0): 125.0259246826172,
#   datetime.datetime(2021, 5, 21, 0, 0): 123.17965698242188,
#   datetime.datetime(2021, 5, 24, 0, 0): 124.81968688964844,
#   datetime.datetime(2021, 5, 25, 0, 0): 124.62328338623048,
#   datetime.datetime(2021, 5, 26, 0, 0): 124.57416534423828,
#   datetime.datetime(2021, 5, 27, 0, 0): 123.03234100341795,
#   datetime.datetime(2021, 5, 28, 0, 0): 122.37437438964844,
#   datetime.datetime(2021, 6, 1, 0, 0): 122.05027770996094,
#   datetime.datetime(2021, 6, 2, 0, 0): 122.81627655029295,
#   datetime.datetime(2021, 6, 3, 0, 0): 121.32356262207033,
#   datetime.datetime(2021, 6, 4, 0, 0): 123.63137817382812,
#   datetime.datetime(2021, 6, 7, 0, 0): 123.6412124633789,
#   datetime.datetime(2021, 6, 8, 0, 0): 124.46614837646484,
#   datetime.datetime(2021, 6, 9, 0, 0): 124.84915161132812,
#   datetime.datetime(2021, 6, 10, 0, 0): 123.84744262695312,
#   datetime.datetime(2021, 6, 11, 0, 0): 125.06519317626952,
#   datetime.datetime(2021, 6, 14, 0, 0): 128.1390380859375,
#   datetime.datetime(2021, 6, 15, 0, 0): 127.31414794921876,
#   datetime.datetime(2021, 6, 16, 0, 0): 127.8149642944336,
#   datetime.datetime(2021, 6, 17, 0, 0): 129.425537109375,
#   datetime.datetime(2021, 6, 18, 0, 0): 128.11941528320312,
#   datetime.datetime(2021, 6, 21, 0, 0): 129.92642211914062,
#   datetime.datetime(2021, 6, 22, 0, 0): 131.5762481689453,
#   datetime.datetime(2021, 6, 23, 0, 0): 131.30125427246094,
#   datetime.datetime(2021, 6, 24, 0, 0): 131.0164794921875,
#   datetime.datetime(2021, 6, 25, 0, 0): 130.72186279296875,
#   datetime.datetime(2021, 6, 28, 0, 0): 132.36190795898438,
#   datetime.datetime(2021, 6, 29, 0, 0): 133.8840789794922,
#   datetime.datetime(2021, 6, 30, 0, 0): 134.5028076171875,
#   datetime.datetime(2021, 7, 1, 0, 0): 134.80723571777344,
#   datetime.datetime(2021, 7, 2, 0, 0): 137.448974609375,
#   datetime.datetime(2021, 7, 6, 0, 0): 139.47201538085938,
#   datetime.datetime(2021, 7, 7, 0, 0): 141.97630310058594,
#   datetime.datetime(2021, 7, 8, 0, 0): 140.67010498046875,
#   datetime.datetime(2021, 7, 9, 0, 0): 142.5065460205078,
#   datetime.datetime(2021, 7, 12, 0, 0): 141.90753173828125,
#   datetime.datetime(2021, 7, 13, 0, 0): 143.02708435058594,
#   datetime.datetime(2021, 7, 14, 0, 0): 146.47409057617188,
#   datetime.datetime(2021, 7, 15, 0, 0): 145.81610107421875,
#   datetime.datetime(2021, 7, 16, 0, 0): 143.76364135742188,
#   datetime.datetime(2021, 7, 19, 0, 0): 139.89430236816406,
#   datetime.datetime(2021, 7, 20, 0, 0): 143.5279083251953,
#   datetime.datetime(2021, 7, 21, 0, 0): 142.7913360595703,
#   datetime.datetime(2021, 7, 22, 0, 0): 144.166259765625,
#   datetime.datetime(2021, 7, 23, 0, 0): 145.8946533203125,
#   datetime.datetime(2021, 7, 26, 0, 0): 146.31695556640625,
#   datetime.datetime(2021, 7, 27, 0, 0): 144.13681030273438,
#   datetime.datetime(2021, 7, 28, 0, 0): 142.37890625,
#   datetime.datetime(2021, 7, 29, 0, 0): 143.02708435058594,
#   datetime.datetime(2021, 7, 30, 0, 0): 143.24310302734375,
#   datetime.datetime(2021, 8, 2, 0, 0): 142.90924072265625,
#   datetime.datetime(2021, 8, 3, 0, 0): 144.71620178222656,
#   datetime.datetime(2021, 8, 4, 0, 0): 144.3135528564453,
#   datetime.datetime(2021, 8, 5, 0, 0): 144.42156982421875,
#   datetime.datetime(2021, 8, 6, 0, 0): 143.73312377929688,
#   datetime.datetime(2021, 8, 9, 0, 0): 143.68392944335938,
#   datetime.datetime(2021, 8, 10, 0, 0): 143.20201110839844,
#   datetime.datetime(2021, 8, 11, 0, 0): 143.45773315429688,
#   datetime.datetime(2021, 8, 12, 0, 0): 146.43780517578125,
#   datetime.datetime(2021, 8, 13, 0, 0): 146.64434814453125,
#   datetime.datetime(2021, 8, 16, 0, 0): 148.63111877441406,
#   datetime.datetime(2021, 8, 17, 0, 0): 147.71641540527344,
#   datetime.datetime(2021, 8, 18, 0, 0): 143.9495086669922,
#   datetime.datetime(2021, 8, 19, 0, 0): 144.28387451171875,
#   datetime.datetime(2021, 8, 20, 0, 0): 145.7493438720703,
#   datetime.datetime(2021, 8, 23, 0, 0): 147.2443389892578,
#   datetime.datetime(2021, 8, 24, 0, 0): 147.15579223632812,
#   datetime.datetime(2021, 8, 25, 0, 0): 145.9165496826172,
#   datetime.datetime(2021, 8, 26, 0, 0): 145.11004638671875,
#   datetime.datetime(2021, 8, 27, 0, 0): 146.15260314941406,
#   datetime.datetime(2021, 8, 30, 0, 0): 150.59815979003906,
#   datetime.datetime(2021, 8, 31, 0, 0): 149.3294219970703,
#   datetime.datetime(2021, 9, 1, 0, 0): 149.99819946289062,
#   datetime.datetime(2021, 9, 2, 0, 0): 151.11941528320312,
#   datetime.datetime(2021, 9, 3, 0, 0): 151.7587127685547,
#   datetime.datetime(2021, 9, 7, 0, 0): 154.10935974121094,
#   datetime.datetime(2021, 9, 8, 0, 0): 152.55538940429688,
#   datetime.datetime(2021, 9, 9, 0, 0): 151.5325164794922,
#   datetime.datetime(2021, 9, 10, 0, 0): 146.51651000976562,
#   datetime.datetime(2021, 9, 13, 0, 0): 147.08694458007812,
#   datetime.datetime(2021, 9, 14, 0, 0): 145.6804962158203,
#   datetime.datetime(2021, 9, 15, 0, 0): 146.5755157470703,
#   datetime.datetime(2021, 9, 16, 0, 0): 146.33946228027344,
#   datetime.datetime(2021, 9, 17, 0, 0): 143.65443420410156,
#   datetime.datetime(2021, 9, 20, 0, 0): 140.5858154296875,
#   datetime.datetime(2021, 9, 21, 0, 0): 141.0677490234375,
#   datetime.datetime(2021, 9, 22, 0, 0): 143.44789123535156,
#   datetime.datetime(2021, 9, 23, 0, 0): 144.41175842285156,
#   datetime.datetime(2021, 9, 24, 0, 0): 144.50027465820312,
#   datetime.datetime(2021, 9, 27, 0, 0): 142.97581481933594,
#   datetime.datetime(2021, 9, 28, 0, 0): 139.57278442382812,
#   datetime.datetime(2021, 9, 29, 0, 0): 140.47764587402344,
#   datetime.datetime(2021, 9, 30, 0, 0): 139.16952514648438,
#   datetime.datetime(2021, 10, 1, 0, 0): 140.30056762695312,
#   datetime.datetime(2021, 10, 4, 0, 0): 136.84840393066406,
#   datetime.datetime(2021, 10, 5, 0, 0): 138.78598022460938,
#   datetime.datetime(2021, 10, 6, 0, 0): 139.6613311767578,
#   datetime.datetime(2021, 10, 7, 0, 0): 140.9300537109375,
#   datetime.datetime(2021, 10, 8, 0, 0): 140.5464324951172,
#   datetime.datetime(2021, 10, 11, 0, 0): 140.45794677734375,
#   datetime.datetime(2021, 10, 12, 0, 0): 139.1793670654297,
#   datetime.datetime(2021, 10, 13, 0, 0): 138.5892791748047,
#   datetime.datetime(2021, 10, 14, 0, 0): 141.39230346679688,
#   datetime.datetime(2021, 10, 15, 0, 0): 142.45452880859375,
#   datetime.datetime(2021, 10, 18, 0, 0): 144.13636779785156,
#   datetime.datetime(2021, 10, 19, 0, 0): 146.30995178222656,
#   datetime.datetime(2021, 10, 20, 0, 0): 146.8016815185547,
#   datetime.datetime(2021, 10, 21, 0, 0): 147.01809692382812,
#   datetime.datetime(2021, 10, 22, 0, 0): 146.24110412597656,
#   datetime.datetime(2021, 10, 25, 0, 0): 146.1919403076172,
#   datetime.datetime(2021, 10, 26, 0, 0): 146.8607635498047,
#   datetime.datetime(2021, 10, 27, 0, 0): 146.3985137939453,
#   datetime.datetime(2021, 10, 28, 0, 0): 150.05722045898438,
#   datetime.datetime(2021, 10, 29, 0, 0): 147.33285522460938,
#   datetime.datetime(2021, 11, 1, 0, 0): 146.50668334960938,
#   datetime.datetime(2021, 11, 2, 0, 0): 147.54922485351562,
#   datetime.datetime(2021, 11, 3, 0, 0): 148.99502563476562,
#   datetime.datetime(2021, 11, 4, 0, 0): 148.4737548828125,
#   datetime.datetime(2021, 11, 5, 0, 0): 149.00563049316406,
#   datetime.datetime(2021, 11, 8, 0, 0): 148.17825317382812,
#   datetime.datetime(2021, 11, 9, 0, 0): 148.5426788330078,
#   datetime.datetime(2021, 11, 10, 0, 0): 145.6961212158203,
#   datetime.datetime(2021, 11, 11, 0, 0): 145.6468963623047,
#   datetime.datetime(2021, 11, 12, 0, 0): 147.7350311279297,
#   datetime.datetime(2021, 11, 15, 0, 0): 147.744873046875,
#   datetime.datetime(2021, 11, 16, 0, 0): 148.7298126220703,
#   datetime.datetime(2021, 11, 17, 0, 0): 151.182373046875,
#   datetime.datetime(2021, 11, 18, 0, 0): 155.4965362548828,
#   datetime.datetime(2021, 11, 19, 0, 0): 158.13626098632812,
#   datetime.datetime(2021, 11, 22, 0, 0): 158.5991973876953,
#   datetime.datetime(2021, 11, 23, 0, 0): 158.98330688476562,
#   datetime.datetime(2021, 11, 24, 0, 0): 159.50535583496094,
#   datetime.datetime(2021, 11, 26, 0, 0): 154.45245361328125,
#   datetime.datetime(2021, 11, 29, 0, 0): 157.83090209960938,
#   datetime.datetime(2021, 11, 30, 0, 0): 162.81484985351562,
#   datetime.datetime(2021, 12, 1, 0, 0): 162.29281616210938,
#   datetime.datetime(2021, 12, 2, 0, 0): 161.29800415039062,
#   datetime.datetime(2021, 12, 3, 0, 0): 159.4068603515625,
#   datetime.datetime(2021, 12, 6, 0, 0): 162.8345489501953,
#   datetime.datetime(2021, 12, 7, 0, 0): 168.6063995361328,
#   datetime.datetime(2021, 12, 8, 0, 0): 172.4477996826172,
#   datetime.datetime(2021, 12, 9, 0, 0): 171.9356231689453,
#   datetime.datetime(2021, 12, 10, 0, 0): 176.75210571289062,
#   datetime.datetime(2021, 12, 13, 0, 0): 173.09786987304688,
#   datetime.datetime(2021, 12, 14, 0, 0): 171.70907592773438,
#   datetime.datetime(2021, 12, 15, 0, 0): 176.6043701171875,
#   datetime.datetime(2021, 12, 16, 0, 0): 169.67019653320312,
#   datetime.datetime(2021, 12, 17, 0, 0): 168.56703186035156,
#   datetime.datetime(2021, 12, 20, 0, 0): 167.19793701171875,
#   datetime.datetime(2021, 12, 21, 0, 0): 170.3892364501953,
#   datetime.datetime(2021, 12, 22, 0, 0): 172.99937438964844,
#   datetime.datetime(2021, 12, 23, 0, 0): 173.6297607421875,
#   datetime.datetime(2021, 12, 27, 0, 0): 177.61886596679688,
#   datetime.datetime(2021, 12, 28, 0, 0): 176.59451293945312,
#   datetime.datetime(2021, 12, 29, 0, 0): 176.68313598632812,
#   datetime.datetime(2021, 12, 30, 0, 0): 175.52088928222656,
#   datetime.datetime(2021, 12, 31, 0, 0): 174.90032958984375,
#   datetime.datetime(2022, 1, 3, 0, 0): 179.2736053466797,
#   datetime.datetime(2022, 1, 4, 0, 0): 176.99835205078125,
#   datetime.datetime(2022, 1, 5, 0, 0): 172.29019165039062,
#   datetime.datetime(2022, 1, 6, 0, 0): 169.41412353515625,
#   datetime.datetime(2022, 1, 7, 0, 0): 169.58157348632812,
#   datetime.datetime(2022, 1, 10, 0, 0): 169.60125732421875,
#   datetime.datetime(2022, 1, 11, 0, 0): 172.4477996826172,
#   datetime.datetime(2022, 1, 12, 0, 0): 172.8910369873047,
#   datetime.datetime(2022, 1, 13, 0, 0): 169.60125732421875,
#   datetime.datetime(2022, 1, 14, 0, 0): 170.46803283691406,
#   datetime.datetime(2022, 1, 18, 0, 0): 167.2471923828125,
#   datetime.datetime(2022, 1, 19, 0, 0): 163.73086547851562,
#   datetime.datetime(2022, 1, 20, 0, 0): 162.0366973876953,
#   datetime.datetime(2022, 1, 21, 0, 0): 159.96829223632812,
#   datetime.datetime(2022, 1, 24, 0, 0): 159.19017028808594,
#   datetime.datetime(2022, 1, 25, 0, 0): 157.3778076171875,
#   datetime.datetime(2022, 1, 26, 0, 0): 157.2891845703125,
#   datetime.datetime(2022, 1, 27, 0, 0): 156.82626342773438,
#   datetime.datetime(2022, 1, 28, 0, 0): 167.76922607421875,
#   datetime.datetime(2022, 1, 31, 0, 0): 172.15231323242188,
#   datetime.datetime(2022, 2, 1, 0, 0): 171.98487854003906,
#   datetime.datetime(2022, 2, 2, 0, 0): 173.19638061523438,
#   datetime.datetime(2022, 2, 3, 0, 0): 170.30055236816406,
#   datetime.datetime(2022, 2, 4, 0, 0): 170.0145721435547,
#   datetime.datetime(2022, 2, 7, 0, 0): 169.29464721679688,
#   datetime.datetime(2022, 2, 8, 0, 0): 172.42095947265625,
#   datetime.datetime(2022, 2, 9, 0, 0): 173.85096740722656,
#   datetime.datetime(2022, 2, 10, 0, 0): 169.74827575683594,
#   datetime.datetime(2022, 2, 11, 0, 0): 166.3162384033203,
#   datetime.datetime(2022, 2, 14, 0, 0): 166.55294799804688,
#   datetime.datetime(2022, 2, 15, 0, 0): 170.40904235839844,
#   datetime.datetime(2022, 2, 16, 0, 0): 170.17237854003906,
#   datetime.datetime(2022, 2, 17, 0, 0): 166.55294799804688,
#   datetime.datetime(2022, 2, 18, 0, 0): 164.9947052001953,
#   datetime.datetime(2022, 2, 22, 0, 0): 162.05577087402344,
#   datetime.datetime(2022, 2, 23, 0, 0): 157.86434936523438,
#   datetime.datetime(2022, 2, 24, 0, 0): 160.49755859375,
#   datetime.datetime(2022, 2, 25, 0, 0): 162.5784912109375,
#   datetime.datetime(2022, 2, 28, 0, 0): 162.84478759765625,
#   datetime.datetime(2022, 3, 1, 0, 0): 160.95118713378906,
#   datetime.datetime(2022, 3, 2, 0, 0): 164.26492309570312,
#   datetime.datetime(2022, 3, 3, 0, 0): 163.939453125,
#   datetime.datetime(2022, 3, 4, 0, 0): 160.92161560058594,
#   datetime.datetime(2022, 3, 7, 0, 0): 157.1049346923828,
#   datetime.datetime(2022, 3, 8, 0, 0): 155.2705841064453,
#   datetime.datetime(2022, 3, 9, 0, 0): 160.70465087890625,
#   datetime.datetime(2022, 3, 10, 0, 0): 156.335693359375,
#   datetime.datetime(2022, 3, 11, 0, 0): 152.59791564941406,
#   datetime.datetime(2022, 3, 14, 0, 0): 148.54454040527344,
#   datetime.datetime(2022, 3, 15, 0, 0): 152.95294189453125,
#   datetime.datetime(2022, 3, 16, 0, 0): 157.3909454345703,
#   datetime.datetime(2022, 3, 17, 0, 0): 158.40676879882812,
#   datetime.datetime(2022, 3, 18, 0, 0): 161.72044372558594,
#   datetime.datetime(2022, 3, 21, 0, 0): 163.10116577148438,
#   datetime.datetime(2022, 3, 22, 0, 0): 166.49378967285156,
#   datetime.datetime(2022, 3, 23, 0, 0): 167.8646240234375,
#   datetime.datetime(2022, 3, 24, 0, 0): 171.67141723632812,
#   datetime.datetime(2022, 3, 25, 0, 0): 172.31246948242188,
#   datetime.datetime(2022, 3, 28, 0, 0): 173.18035888671875,
#   datetime.datetime(2022, 3, 29, 0, 0): 176.49404907226562,
#   datetime.datetime(2022, 3, 30, 0, 0): 175.3204345703125,
#   datetime.datetime(2022, 3, 31, 0, 0): 172.20401000976562,
#   datetime.datetime(2022, 4, 1, 0, 0): 171.90809631347656,
#   datetime.datetime(2022, 4, 4, 0, 0): 175.981201171875,
#   datetime.datetime(2022, 4, 5, 0, 0): 172.64779663085938,
#   datetime.datetime(2022, 4, 6, 0, 0): 169.4622802734375,
#   datetime.datetime(2022, 4, 7, 0, 0): 169.76803588867188,
#   datetime.datetime(2022, 4, 8, 0, 0): 167.7462921142578,
#   datetime.datetime(2022, 4, 11, 0, 0): 163.46604919433594,
#   datetime.datetime(2022, 4, 12, 0, 0): 165.3497772216797,
#   datetime.datetime(2022, 4, 13, 0, 0): 168.052001953125,
#   datetime.datetime(2022, 4, 14, 0, 0): 163.01243591308594,
#   datetime.datetime(2022, 4, 18, 0, 0): 162.7954559326172,
#   datetime.datetime(2022, 4, 19, 0, 0): 165.09332275390625,
#   datetime.datetime(2022, 4, 20, 0, 0): 164.92567443847656,
#   datetime.datetime(2022, 4, 21, 0, 0): 164.1268310546875,
#   datetime.datetime(2022, 4, 22, 0, 0): 159.56063842773438,
#   datetime.datetime(2022, 4, 25, 0, 0): 160.63563537597656,
#   datetime.datetime(2022, 4, 26, 0, 0): 154.639404296875,
#   datetime.datetime(2022, 4, 27, 0, 0): 154.41256713867188,
#   datetime.datetime(2022, 4, 28, 0, 0): 161.38514709472656,
#   datetime.datetime(2022, 4, 29, 0, 0): 155.4776611328125,
#   datetime.datetime(2022, 5, 2, 0, 0): 155.7834014892578,
#   datetime.datetime(2022, 5, 3, 0, 0): 157.28245544433594,
#   datetime.datetime(2022, 5, 4, 0, 0): 163.73236083984375,
#   datetime.datetime(2022, 5, 5, 0, 0): 154.60980224609375,
#   datetime.datetime(2022, 5, 6, 0, 0): 155.34071350097656,
#   datetime.datetime(2022, 5, 9, 0, 0): 150.18504333496094,
#   datetime.datetime(2022, 5, 10, 0, 0): 152.60484313964844,
#   datetime.datetime(2022, 5, 11, 0, 0): 144.693603515625,
#   datetime.datetime(2022, 5, 12, 0, 0): 140.80218505859375,
#   datetime.datetime(2022, 5, 13, 0, 0): 145.29608154296875,
#   datetime.datetime(2022, 5, 16, 0, 0): 143.7454376220703,
#   datetime.datetime(2022, 5, 17, 0, 0): 147.39981079101562,
#   datetime.datetime(2022, 5, 18, 0, 0): 139.08364868164062,
#   datetime.datetime(2022, 5, 19, 0, 0): 135.65643310546875,
#   datetime.datetime(2022, 5, 20, 0, 0): 135.89346313476562,
#   datetime.datetime(2022, 5, 23, 0, 0): 141.3454132080078,
#   datetime.datetime(2022, 5, 24, 0, 0): 138.62933349609375,
#   datetime.datetime(2022, 5, 25, 0, 0): 138.787353515625,
#   datetime.datetime(2022, 5, 26, 0, 0): 142.0071563720703,
#   datetime.datetime(2022, 5, 27, 0, 0): 147.79490661621094,
#   datetime.datetime(2022, 5, 31, 0, 0): 147.00474548339844,
#   datetime.datetime(2022, 6, 1, 0, 0): 146.87637329101562,
#   datetime.datetime(2022, 6, 2, 0, 0): 149.34555053710938,
#   datetime.datetime(2022, 6, 3, 0, 0): 143.58741760253906,
#   datetime.datetime(2022, 6, 6, 0, 0): 144.33804321289062,
#   datetime.datetime(2022, 6, 7, 0, 0): 146.87637329101562,
#   datetime.datetime(2022, 6, 8, 0, 0): 146.13560485839844,
#   datetime.datetime(2022, 6, 9, 0, 0): 140.8811798095703,
#   datetime.datetime(2022, 6, 10, 0, 0): 135.43914794921875,
#   datetime.datetime(2022, 6, 13, 0, 0): 130.25389099121094,
#   datetime.datetime(2022, 6, 14, 0, 0): 131.12303161621094,
#   datetime.datetime(2022, 6, 15, 0, 0): 133.76010131835938,
#   datetime.datetime(2022, 6, 16, 0, 0): 128.45631408691406,
#   datetime.datetime(2022, 6, 17, 0, 0): 129.93780517578125,
#   datetime.datetime(2022, 6, 21, 0, 0): 134.19467163085938,
#   datetime.datetime(2022, 6, 22, 0, 0): 133.68112182617188,
#   datetime.datetime(2022, 6, 23, 0, 0): 136.56507873535156,
#   datetime.datetime(2022, 6, 24, 0, 0): 139.91329956054688,
#   datetime.datetime(2022, 6, 27, 0, 0): 139.91329956054688,
#   datetime.datetime(2022, 6, 28, 0, 0): 135.7453155517578,
#   datetime.datetime(2022, 6, 29, 0, 0): 137.51324462890625,
#   datetime.datetime(2022, 6, 30, 0, 0): 135.03419494628906,
#   datetime.datetime(2022, 7, 1, 0, 0): 137.21693420410156,
#   datetime.datetime(2022, 7, 5, 0, 0): 139.8145294189453,
#   datetime.datetime(2022, 7, 6, 0, 0): 141.15774536132812,
#   datetime.datetime(2022, 7, 7, 0, 0): 144.54544067382812,
#   datetime.datetime(2022, 7, 8, 0, 0): 145.22694396972656,
#   datetime.datetime(2022, 7, 11, 0, 0): 143.08370971679688,
#   datetime.datetime(2022, 7, 12, 0, 0): 144.06149291992188,
#   datetime.datetime(2022, 7, 13, 0, 0): 143.69606018066406,
#   datetime.datetime(2022, 7, 14, 0, 0): 146.6393280029297,
#   datetime.datetime(2022, 7, 15, 0, 0): 148.31834411621094,
#   datetime.datetime(2022, 7, 18, 0, 0): 145.25657653808594,
#   datetime.datetime(2022, 7, 19, 0, 0): 149.13812255859375,
#   datetime.datetime(2022, 7, 20, 0, 0): 151.1529541015625,
#   datetime.datetime(2022, 7, 21, 0, 0): 153.43446350097656,
#   datetime.datetime(2022, 7, 22, 0, 0): 152.19003295898438,
#   datetime.datetime(2022, 7, 25, 0, 0): 151.06407165527344,
#   datetime.datetime(2022, 7, 26, 0, 0): 149.730712890625,
#   datetime.datetime(2022, 7, 27, 0, 0): 154.85670471191406,
#   datetime.datetime(2022, 7, 28, 0, 0): 155.40982055664062,
#   datetime.datetime(2022, 7, 29, 0, 0): 160.5062255859375,
#   datetime.datetime(2022, 8, 1, 0, 0): 159.51852416992188,
#   datetime.datetime(2022, 8, 2, 0, 0): 158.03701782226562,
#   datetime.datetime(2022, 8, 3, 0, 0): 164.08157348632812,
#   datetime.datetime(2022, 8, 4, 0, 0): 163.76547241210938,
#   datetime.datetime(2022, 8, 5, 0, 0): 163.53802490234375,
#   datetime.datetime(2022, 8, 8, 0, 0): 163.06329345703125,
#   datetime.datetime(2022, 8, 9, 0, 0): 163.1127471923828,
#   datetime.datetime(2022, 8, 10, 0, 0): 167.3854217529297,
#   datetime.datetime(2022, 8, 11, 0, 0): 166.6436004638672,
#   datetime.datetime(2022, 8, 12, 0, 0): 170.21405029296875,
#   datetime.datetime(2022, 8, 15, 0, 0): 171.2921142578125,
#   datetime.datetime(2022, 8, 16, 0, 0): 171.1338348388672,
#   datetime.datetime(2022, 8, 17, 0, 0): 172.63722229003906,
#   datetime.datetime(2022, 8, 18, 0, 0): 172.24160766601562,
#   datetime.datetime(2022, 8, 19, 0, 0): 169.64041137695312,
#   datetime.datetime(2022, 8, 22, 0, 0): 165.7337188720703,
#   datetime.datetime(2022, 8, 23, 0, 0): 165.39743041992188,
#   datetime.datetime(2022, 8, 24, 0, 0): 165.6941375732422,
#   datetime.datetime(2022, 8, 25, 0, 0): 168.16676330566406,
#   datetime.datetime(2022, 8, 26, 0, 0): 161.8269805908203,
#   datetime.datetime(2022, 8, 29, 0, 0): 159.61155700683594,
#   datetime.datetime(2022, 8, 30, 0, 0): 157.16860961914062,
#   datetime.datetime(2022, 8, 31, 0, 0): 155.49713134765625,
#   datetime.datetime(2022, 9, 1, 0, 0): 156.22900390625,
#   datetime.datetime(2022, 9, 2, 0, 0): 154.1025848388672,
#   datetime.datetime(2022, 9, 6, 0, 0): 152.83660888671875,
#   datetime.datetime(2022, 9, 7, 0, 0): 154.2509307861328,
#   datetime.datetime(2022, 9, 8, 0, 0): 152.76736450195312,
#   datetime.datetime(2022, 9, 9, 0, 0): 155.64547729492188,
#   datetime.datetime(2022, 9, 12, 0, 0): 161.63905334472656,
#   datetime.datetime(2022, 9, 13, 0, 0): 152.15415954589844,
#   datetime.datetime(2022, 9, 14, 0, 0): 153.60804748535156,
#   datetime.datetime(2022, 9, 15, 0, 0): 150.7002410888672,
#   datetime.datetime(2022, 9, 16, 0, 0): 149.04856872558594,
#   datetime.datetime(2022, 9, 19, 0, 0): 152.78713989257812,
#   datetime.datetime(2022, 9, 20, 0, 0): 155.18060302734375,
#   datetime.datetime(2022, 9, 21, 0, 0): 152.0354766845703,
#   datetime.datetime(2022, 9, 22, 0, 0): 151.0662078857422,
#   datetime.datetime(2022, 9, 23, 0, 0): 148.78150939941406,
#   datetime.datetime(2022, 9, 26, 0, 0): 149.1177978515625,
#   datetime.datetime(2022, 9, 27, 0, 0): 150.09693908691406,
#   datetime.datetime(2022, 9, 28, 0, 0): 148.19798278808594,
#   datetime.datetime(2022, 9, 29, 0, 0): 140.9186553955078,
#   datetime.datetime(2022, 9, 30, 0, 0): 136.685546875,
#   datetime.datetime(2022, 10, 3, 0, 0): 140.8889617919922,
#   datetime.datetime(2022, 10, 4, 0, 0): 144.4989776611328,
#   datetime.datetime(2022, 10, 5, 0, 0): 144.79568481445312,
#   datetime.datetime(2022, 10, 6, 0, 0): 143.83631896972656,
#   datetime.datetime(2022, 10, 7, 0, 0): 138.55482482910156,
#   datetime.datetime(2022, 10, 10, 0, 0): 138.88119506835938,
#   datetime.datetime(2022, 10, 11, 0, 0): 137.4569854736328,
#   datetime.datetime(2022, 10, 12, 0, 0): 136.82398986816406,
#   datetime.datetime(2022, 10, 13, 0, 0): 141.42308044433594,
#   datetime.datetime(2022, 10, 14, 0, 0): 136.86358642578125,
#   datetime.datetime(2022, 10, 17, 0, 0): 140.84942626953125,
#   datetime.datetime(2022, 10, 18, 0, 0): 142.17471313476562,
#   datetime.datetime(2022, 10, 19, 0, 0): 142.2835235595703,
#   datetime.datetime(2022, 10, 20, 0, 0): 141.8186492919922,
#   datetime.datetime(2022, 10, 21, 0, 0): 145.6561737060547,
#   datetime.datetime(2022, 10, 24, 0, 0): 147.812255859375,
#   datetime.datetime(2022, 10, 25, 0, 0): 150.67059326171875,
#   datetime.datetime(2022, 10, 26, 0, 0): 147.71339416503906,
#   datetime.datetime(2022, 10, 27, 0, 0): 143.2132110595703,
#   datetime.datetime(2022, 10, 28, 0, 0): 154.0333251953125,
#   datetime.datetime(2022, 10, 31, 0, 0): 151.6596221923828,
#   datetime.datetime(2022, 11, 1, 0, 0): 148.9990997314453,
#   datetime.datetime(2022, 11, 2, 0, 0): 143.44068908691406,
#   datetime.datetime(2022, 11, 3, 0, 0): 137.3581085205078,
#   datetime.datetime(2022, 11, 4, 0, 0): 137.09060668945312,
#   datetime.datetime(2022, 11, 7, 0, 0): 137.6255645751953,
#   datetime.datetime(2022, 11, 8, 0, 0): 138.20018005371094,
#   datetime.datetime(2022, 11, 9, 0, 0): 133.61329650878906,
#   datetime.datetime(2022, 11, 10, 0, 0): 145.50149536132812,
#   datetime.datetime(2022, 11, 11, 0, 0): 148.30511474609375,
#   datetime.datetime(2022, 11, 14, 0, 0): 146.89834594726562,
#   datetime.datetime(2022, 11, 15, 0, 0): 148.64195251464844,
#   datetime.datetime(2022, 11, 16, 0, 0): 147.4036102294922,
#   datetime.datetime(2022, 11, 17, 0, 0): 149.3156280517578,
#   datetime.datetime(2022, 11, 18, 0, 0): 149.8803253173828,
#   datetime.datetime(2022, 11, 21, 0, 0): 146.630859375,
#   datetime.datetime(2022, 11, 22, 0, 0): 148.7806396484375,
#   datetime.datetime(2022, 11, 23, 0, 0): 149.662353515625,
#   datetime.datetime(2022, 11, 25, 0, 0): 146.72996520996094,
#   datetime.datetime(2022, 11, 28, 0, 0): 142.876220703125,
#   datetime.datetime(2022, 11, 29, 0, 0): 139.85462951660156,
#   datetime.datetime(2022, 11, 30, 0, 0): 146.6507110595703,
#   datetime.datetime(2022, 12, 1, 0, 0): 146.92808532714844,
#   datetime.datetime(2022, 12, 2, 0, 0): 146.43275451660156,
#   datetime.datetime(2022, 12, 5, 0, 0): 145.26373291015625,
#   datetime.datetime(2022, 12, 6, 0, 0): 141.5784149169922,
#   datetime.datetime(2022, 12, 7, 0, 0): 139.6267547607422,
#   datetime.datetime(2022, 12, 8, 0, 0): 141.32081604003906,
#   datetime.datetime(2022, 12, 9, 0, 0): 140.8354034423828,
#   datetime.datetime(2022, 12, 12, 0, 0): 143.1436767578125,
#   datetime.datetime(2022, 12, 13, 0, 0): 144.11456298828125,
#   datetime.datetime(2022, 12, 14, 0, 0): 141.87559509277344,
#   datetime.datetime(2022, 12, 15, 0, 0): 135.22813415527344,
#   datetime.datetime(2022, 12, 16, 0, 0): 133.25665283203125,
#   datetime.datetime(2022, 12, 19, 0, 0): 131.13661193847656,
#   datetime.datetime(2022, 12, 20, 0, 0): 131.06729125976562,
#   datetime.datetime(2022, 12, 21, 0, 0): 134.1879119873047,
#   datetime.datetime(2022, 12, 22, 0, 0): 130.9979248046875,
#   datetime.datetime(2022, 12, 23, 0, 0): 130.63134765625,
#   datetime.datetime(2022, 12, 27, 0, 0): 128.81842041015625,
#   datetime.datetime(2022, 12, 28, 0, 0): 124.8656005859375,
#   datetime.datetime(2022, 12, 29, 0, 0): 128.40234375,
#   datetime.datetime(2022, 12, 30, 0, 0): 128.71934509277344,
#   datetime.datetime(2023, 1, 3, 0, 0): 123.90462493896484,
#   datetime.datetime(2023, 1, 4, 0, 0): 125.18260955810548,
#   datetime.datetime(2023, 1, 5, 0, 0): 123.85509490966795,
#   datetime.datetime(2023, 1, 6, 0, 0): 128.4122314453125,
#   datetime.datetime(2023, 1, 9, 0, 0): 128.93728637695312,
#   datetime.datetime(2023, 1, 10, 0, 0): 129.51190185546875,
#   datetime.datetime(2023, 1, 11, 0, 0): 132.2461700439453,
#   datetime.datetime(2023, 1, 12, 0, 0): 132.16690063476562,
#   datetime.datetime(2023, 1, 13, 0, 0): 133.5043182373047,
#   datetime.datetime(2023, 1, 17, 0, 0): 134.67337036132812,
#   datetime.datetime(2023, 1, 18, 0, 0): 133.9501495361328,
#   datetime.datetime(2023, 1, 19, 0, 0): 134.00958251953125,
#   datetime.datetime(2023, 1, 20, 0, 0): 136.58534240722656,
#   datetime.datetime(2023, 1, 23, 0, 0): 139.795166015625,
#   datetime.datetime(2023, 1, 24, 0, 0): 141.2019500732422,
#   datetime.datetime(2023, 1, 25, 0, 0): 140.53817749023438,
#   datetime.datetime(2023, 1, 26, 0, 0): 142.61863708496094,
#   datetime.datetime(2023, 1, 27, 0, 0): 144.5702667236328,
#   datetime.datetime(2023, 1, 30, 0, 0): 141.66758728027344,
#   datetime.datetime(2023, 1, 31, 0, 0): 142.94554138183594,
#   datetime.datetime(2023, 2, 1, 0, 0): 144.07492065429688,
#   datetime.datetime(2023, 2, 2, 0, 0): 149.41468811035156,
#   datetime.datetime(2023, 2, 3, 0, 0): 153.06040954589844,
#   datetime.datetime(2023, 2, 6, 0, 0): 150.3162078857422,
#   datetime.datetime(2023, 2, 7, 0, 0): 153.20899963378906,
#   datetime.datetime(2023, 2, 8, 0, 0): 150.50445556640625,
#   datetime.datetime(2023, 2, 9, 0, 0): 149.46424865722656,
#   datetime.datetime(2023, 2, 10, 0, 0): 149.83132934570312,
#   datetime.datetime(2023, 2, 13, 0, 0): 152.64918518066406,
#   datetime.datetime(2023, 2, 14, 0, 0): 152.00424194335938,
#   datetime.datetime(2023, 2, 15, 0, 0): 154.1176300048828,
#   datetime.datetime(2023, 2, 16, 0, 0): 152.51026916503906,
#   datetime.datetime(2023, 2, 17, 0, 0): 151.35931396484375,
#   datetime.datetime(2023, 2, 21, 0, 0): 147.32107543945312,
#   datetime.datetime(2023, 2, 22, 0, 0): 147.7477569580078,
#   datetime.datetime(2023, 2, 23, 0, 0): 148.23390197753906,
#   datetime.datetime(2023, 2, 24, 0, 0): 145.56492614746094,
#   datetime.datetime(2023, 2, 27, 0, 0): 146.7654571533203,
#   datetime.datetime(2023, 2, 28, 0, 0): 146.2594451904297,
#   datetime.datetime(2023, 3, 1, 0, 0): 144.17584228515625,
#   datetime.datetime(2023, 3, 2, 0, 0): 144.77114868164062,
#   datetime.datetime(2023, 3, 3, 0, 0): 149.8511962890625,
#   datetime.datetime(2023, 3, 6, 0, 0): 152.62933349609375,
#   datetime.datetime(2023, 3, 7, 0, 0): 150.41673278808594,
#   datetime.datetime(2023, 3, 8, 0, 0): 151.6768341064453,
#   datetime.datetime(2023, 3, 9, 0, 0): 149.4146270751953,
#   datetime.datetime(2023, 3, 10, 0, 0): 147.3409423828125,
#   datetime.datetime(2023, 3, 13, 0, 0): 149.29556274414062,
#   datetime.datetime(2023, 3, 14, 0, 0): 151.3990020751953,
#   datetime.datetime(2023, 3, 15, 0, 0): 151.7958984375,
#   datetime.datetime(2023, 3, 16, 0, 0): 154.63356018066406,
#   datetime.datetime(2023, 3, 17, 0, 0): 153.7902069091797,
# ...
#   datetime.datetime(2022, 11, 25, 0, 0): 28.29190826416016,
#   datetime.datetime(2022, 11, 28, 0, 0): 27.70369911193848,
#   datetime.datetime(2022, 11, 29, 0, 0): 27.867626190185547,
#   datetime.datetime(2022, 11, 30, 0, 0): 28.995834350585938,
#   datetime.datetime(2022, 12, 1, 0, 0): 28.764406204223636,
#   datetime.datetime(2022, 12, 2, 0, 0): 28.35940933227539,
#   datetime.datetime(2022, 12, 5, 0, 0): 28.12798118591309,
#   datetime.datetime(2022, 12, 6, 0, 0): 27.57834243774414,
#   datetime.datetime(2022, 12, 7, 0, 0): 27.317991256713867,
#   datetime.datetime(2022, 12, 8, 0, 0): 27.42405891418457,
#   datetime.datetime(2022, 12, 9, 0, 0): 27.231203079223636,
#   datetime.datetime(2022, 12, 12, 0, 0): 27.665132522583008,
#   datetime.datetime(2022, 12, 13, 0, 0): 27.70369911193848,
#   datetime.datetime(2022, 12, 14, 0, 0): 27.25048828125,
#   datetime.datetime(2022, 12, 15, 0, 0): 26.180139541625977,
#   datetime.datetime(2022, 12, 16, 0, 0): 25.958356857299805,
#   datetime.datetime(2022, 12, 19, 0, 0): 25.8330020904541,
#   datetime.datetime(2022, 12, 20, 0, 0): 25.49550437927246,
#   datetime.datetime(2022, 12, 21, 0, 0): 25.871570587158203,
#   datetime.datetime(2022, 12, 22, 0, 0): 25.042293548583984,
#   datetime.datetime(2022, 12, 23, 0, 0): 25.15800666809082,
#   datetime.datetime(2022, 12, 27, 0, 0): 25.01336479187012,
#   datetime.datetime(2022, 12, 28, 0, 0): 24.627655029296875,
#   datetime.datetime(2022, 12, 29, 0, 0): 25.273719787597656,
#   datetime.datetime(2022, 12, 30, 0, 0): 25.48586082458496,
#   datetime.datetime(2023, 1, 3, 0, 0): 25.77514266967773,
#   datetime.datetime(2023, 1, 4, 0, 0): 26.69120979309082,
#   datetime.datetime(2023, 1, 5, 0, 0): 26.57549476623535,
#   datetime.datetime(2023, 1, 6, 0, 0): 27.70369911193848,
#   datetime.datetime(2023, 1, 9, 0, 0): 28.262983322143555,
#   datetime.datetime(2023, 1, 10, 0, 0): 28.38833999633789,
#   datetime.datetime(2023, 1, 11, 0, 0): 28.783689498901367,
#   datetime.datetime(2023, 1, 12, 0, 0): 29.20797348022461,
#   datetime.datetime(2023, 1, 13, 0, 0): 29.034406661987305,
#   datetime.datetime(2023, 1, 17, 0, 0): 28.54262351989746,
#   datetime.datetime(2023, 1, 18, 0, 0): 27.780841827392575,
#   datetime.datetime(2023, 1, 19, 0, 0): 27.40477561950684,
#   datetime.datetime(2023, 1, 20, 0, 0): 28.17619514465332,
#   datetime.datetime(2023, 1, 23, 0, 0): 29.18868827819824,
#   datetime.datetime(2023, 1, 24, 0, 0): 28.8511905670166,
#   datetime.datetime(2023, 1, 25, 0, 0): 28.639049530029297,
#   datetime.datetime(2023, 1, 26, 0, 0): 29.015117645263672,
#   datetime.datetime(2023, 1, 27, 0, 0): 27.154062271118164,
#   datetime.datetime(2023, 1, 30, 0, 0): 26.95156478881836,
#   datetime.datetime(2023, 1, 31, 0, 0): 27.25048828125,
#   datetime.datetime(2023, 2, 1, 0, 0): 28.03155517578125,
#   datetime.datetime(2023, 2, 2, 0, 0): 29.11154556274414,
#   datetime.datetime(2023, 2, 3, 0, 0): 29.236900329589844,
#   datetime.datetime(2023, 2, 6, 0, 0): 28.00222969055176,
#   datetime.datetime(2023, 2, 7, 0, 0): 28.353595733642575,
#   datetime.datetime(2023, 2, 8, 0, 0): 27.56301498413086,
#   datetime.datetime(2023, 2, 9, 0, 0): 27.06524085998535,
#   datetime.datetime(2023, 2, 10, 0, 0): 27.13356208801269,
#   datetime.datetime(2023, 2, 13, 0, 0): 27.86557960510254,
#   datetime.datetime(2023, 2, 14, 0, 0): 27.953426361083984,
#   datetime.datetime(2023, 2, 15, 0, 0): 28.15839385986328,
#   datetime.datetime(2023, 2, 16, 0, 0): 27.52397346496582,
#   datetime.datetime(2023, 2, 17, 0, 0): 26.948118209838867,
#   datetime.datetime(2023, 2, 21, 0, 0): 25.435272216796875,
#   datetime.datetime(2023, 2, 22, 0, 0): 24.859418869018555,
#   datetime.datetime(2023, 2, 23, 0, 0): 24.996063232421875,
#   datetime.datetime(2023, 2, 24, 0, 0): 24.53732681274414,
#   datetime.datetime(2023, 2, 27, 0, 0): 24.303083419799805,
#   datetime.datetime(2023, 2, 28, 0, 0): 24.33236312866211,
#   datetime.datetime(2023, 3, 1, 0, 0): 24.722774505615234,
#   datetime.datetime(2023, 3, 2, 0, 0): 25.57192039489746,
#   datetime.datetime(2023, 3, 3, 0, 0): 25.76712226867676,
#   datetime.datetime(2023, 3, 6, 0, 0): 25.366952896118164,
#   datetime.datetime(2023, 3, 7, 0, 0): 24.91798210144043,
#   datetime.datetime(2023, 3, 8, 0, 0): 25.357192993164062,
#   datetime.datetime(2023, 3, 9, 0, 0): 25.80616569519043,
#   datetime.datetime(2023, 3, 10, 0, 0): 26.56746482849121,
#   datetime.datetime(2023, 3, 13, 0, 0): 26.303939819335938,
#   datetime.datetime(2023, 3, 14, 0, 0): 27.338525772094727,
#   datetime.datetime(2023, 3, 15, 0, 0): 27.72893714904785,
#   datetime.datetime(2023, 3, 16, 0, 0): 29.45650863647461,
#   datetime.datetime(2023, 3, 17, 0, 0): 29.09537506103516,
#   datetime.datetime(2023, 3, 20, 0, 0): 28.46095848083496,
#   datetime.datetime(2023, 3, 21, 0, 0): 27.777738571166992,
#   datetime.datetime(2023, 3, 22, 0, 0): 27.45564842224121,
#   datetime.datetime(2023, 3, 23, 0, 0): 28.33407592773437,
#   datetime.datetime(2023, 3, 24, 0, 0): 28.656164169311523,
#   datetime.datetime(2023, 3, 27, 0, 0): 28.4804801940918,
#   datetime.datetime(2023, 3, 28, 0, 0): 28.58784484863281,
#   datetime.datetime(2023, 3, 29, 0, 0): 30.764387130737305,
#   datetime.datetime(2023, 3, 30, 0, 0): 31.320720672607425,
#   datetime.datetime(2023, 3, 31, 0, 0): 31.88681411743164,
#   datetime.datetime(2023, 4, 3, 0, 0): 32.10154342651367,
#   datetime.datetime(2023, 4, 4, 0, 0): 32.30650329589844,
#   datetime.datetime(2023, 4, 5, 0, 0): 32.04297637939453,
#   datetime.datetime(2023, 4, 6, 0, 0): 32.02346420288086,
#   datetime.datetime(2023, 4, 10, 0, 0): 31.74041175842285,
#   datetime.datetime(2023, 4, 11, 0, 0): 31.574485778808597,
#   datetime.datetime(2023, 4, 12, 0, 0): 31.25239944458008,
#   datetime.datetime(2023, 4, 13, 0, 0): 31.35976219177246,
#   datetime.datetime(2023, 4, 14, 0, 0): 31.125513076782227,
#   datetime.datetime(2023, 4, 17, 0, 0): 31.36952209472656,
#   datetime.datetime(2023, 4, 18, 0, 0): 31.066953659057617,
#   datetime.datetime(2023, 4, 19, 0, 0): 30.403255462646484,
#   datetime.datetime(2023, 4, 20, 0, 0): 30.12020874023437,
#   datetime.datetime(2023, 4, 21, 0, 0): 29.573631286621094,
#   datetime.datetime(2023, 4, 24, 0, 0): 28.94897079467773,
#   datetime.datetime(2023, 4, 25, 0, 0): 28.187671661376957,
#   datetime.datetime(2023, 4, 26, 0, 0): 28.353595733642575,
#   datetime.datetime(2023, 4, 27, 0, 0): 29.14417839050293,
#   datetime.datetime(2023, 4, 28, 0, 0): 30.315412521362305,
#   datetime.datetime(2023, 5, 1, 0, 0): 29.573631286621094,
#   datetime.datetime(2023, 5, 2, 0, 0): 29.056339263916016,
#   datetime.datetime(2023, 5, 3, 0, 0): 29.915239334106445,
#   datetime.datetime(2023, 5, 4, 0, 0): 30.61595726013184,
#   datetime.datetime(2023, 5, 5, 0, 0): 30.37095260620117,
#   datetime.datetime(2023, 5, 8, 0, 0): 30.155345916748047,
#   datetime.datetime(2023, 5, 9, 0, 0): 29.49873352050781,
#   datetime.datetime(2023, 5, 10, 0, 0): 29.37132453918457,
#   datetime.datetime(2023, 5, 11, 0, 0): 28.28350067138672,
#   datetime.datetime(2023, 5, 12, 0, 0): 28.3717041015625,
#   datetime.datetime(2023, 5, 15, 0, 0): 29.204723358154297,
#   datetime.datetime(2023, 5, 16, 0, 0): 28.636308670043945,
#   datetime.datetime(2023, 5, 17, 0, 0): 28.29330062866211,
#   datetime.datetime(2023, 5, 18, 0, 0): 29.087121963500977,
#   datetime.datetime(2023, 5, 19, 0, 0): 29.33212661743164,
#   datetime.datetime(2023, 5, 22, 0, 0): 29.67513465881348,
#   datetime.datetime(2023, 5, 23, 0, 0): 28.920515060424805,
#   datetime.datetime(2023, 5, 24, 0, 0): 28.42070579528809,
#   datetime.datetime(2023, 5, 25, 0, 0): 26.852663040161133,
#   datetime.datetime(2023, 5, 26, 0, 0): 28.42070579528809,
#   datetime.datetime(2023, 5, 30, 0, 0): 29.390928268432617,
#   datetime.datetime(2023, 5, 31, 0, 0): 30.81196403503418,
#   datetime.datetime(2023, 6, 1, 0, 0): 30.508155822753903,
#   datetime.datetime(2023, 6, 2, 0, 0): 30.684558868408203,
#   datetime.datetime(2023, 6, 5, 0, 0): 29.263525009155277,
#   datetime.datetime(2023, 6, 6, 0, 0): 30.341550827026367,
#   datetime.datetime(2023, 6, 7, 0, 0): 30.65515899658203,
#   datetime.datetime(2023, 6, 8, 0, 0): 31.18437385559082,
#   datetime.datetime(2023, 6, 9, 0, 0): 30.71396255493164,
#   datetime.datetime(2023, 6, 12, 0, 0): 32.409400939941406,
#   datetime.datetime(2023, 6, 13, 0, 0): 33.23262405395508,
#   datetime.datetime(2023, 6, 14, 0, 0): 34.869266510009766,
#   datetime.datetime(2023, 6, 15, 0, 0): 35.10447311401367,
#   datetime.datetime(2023, 6, 16, 0, 0): 35.64347839355469,
#   datetime.datetime(2023, 6, 20, 0, 0): 34.30085372924805,
#   datetime.datetime(2023, 6, 21, 0, 0): 32.2427978515625,
#   datetime.datetime(2023, 6, 22, 0, 0): 32.05659484863281,
#   datetime.datetime(2023, 6, 23, 0, 0): 32.34080123901367,
#   datetime.datetime(2023, 6, 26, 0, 0): 32.674007415771484,
#   datetime.datetime(2023, 6, 27, 0, 0): 33.41883087158203,
#   datetime.datetime(2023, 6, 28, 0, 0): 32.899417877197266,
#   datetime.datetime(2023, 6, 29, 0, 0): 32.25259780883789,
#   datetime.datetime(2023, 6, 30, 0, 0): 32.772010803222656,
#   datetime.datetime(2023, 7, 3, 0, 0): 32.94841766357422,
#   datetime.datetime(2023, 7, 5, 0, 0): 31.86059188842773,
#   datetime.datetime(2023, 7, 6, 0, 0): 31.331377029418945,
#   datetime.datetime(2023, 7, 7, 0, 0): 31.21377182006836,
#   datetime.datetime(2023, 7, 10, 0, 0): 32.08599853515625,
#   datetime.datetime(2023, 7, 11, 0, 0): 32.63480758666992,
#   datetime.datetime(2023, 7, 12, 0, 0): 33.30122375488281,
#   datetime.datetime(2023, 7, 13, 0, 0): 33.19342041015625,
#   datetime.datetime(2023, 7, 14, 0, 0): 32.4878044128418,
#   datetime.datetime(2023, 7, 17, 0, 0): 33.683433532714844,
#   datetime.datetime(2023, 7, 18, 0, 0): 33.81083679199219,
#   datetime.datetime(2023, 7, 19, 0, 0): 33.771636962890625,
#   datetime.datetime(2023, 7, 20, 0, 0): 32.703407287597656,
#   datetime.datetime(2023, 7, 21, 0, 0): 33.340423583984375,
#   datetime.datetime(2023, 7, 24, 0, 0): 32.958221435546875,
#   datetime.datetime(2023, 7, 25, 0, 0): 33.41883087158203,
#   datetime.datetime(2023, 7, 26, 0, 0): 33.67363739013672,
#   datetime.datetime(2023, 7, 27, 0, 0): 33.85983657836914,
#   datetime.datetime(2023, 7, 28, 0, 0): 36.09429931640625,
#   datetime.datetime(2023, 7, 31, 0, 0): 35.05546951293945,
#   datetime.datetime(2023, 8, 1, 0, 0): 35.084869384765625,
#   datetime.datetime(2023, 8, 2, 0, 0): 33.703033447265625,
#   datetime.datetime(2023, 8, 3, 0, 0): 34.1734504699707,
#   datetime.datetime(2023, 8, 4, 0, 0): 34.56195068359375,
#   datetime.datetime(2023, 8, 7, 0, 0): 34.65046691894531,
#   datetime.datetime(2023, 8, 8, 0, 0): 34.44392395019531,
#   datetime.datetime(2023, 8, 9, 0, 0): 33.716094970703125,
#   datetime.datetime(2023, 8, 10, 0, 0): 34.10951614379883,
#   datetime.datetime(2023, 8, 11, 0, 0): 34.316062927246094,
#   datetime.datetime(2023, 8, 14, 0, 0): 35.09306716918945,
#   datetime.datetime(2023, 8, 15, 0, 0): 34.198036193847656,
#   datetime.datetime(2023, 8, 16, 0, 0): 32.97843170166016,
#   datetime.datetime(2023, 8, 17, 0, 0): 32.04405975341797,
#   datetime.datetime(2023, 8, 18, 0, 0): 32.21126174926758,
#   datetime.datetime(2023, 8, 21, 0, 0): 32.594852447509766,
#   datetime.datetime(2023, 8, 22, 0, 0): 32.34896469116211,
#   datetime.datetime(2023, 8, 23, 0, 0): 33.4210319519043,
#   datetime.datetime(2023, 8, 24, 0, 0): 32.05389404296875,
#   datetime.datetime(2023, 8, 25, 0, 0): 32.70304107666016,
#   datetime.datetime(2023, 8, 28, 0, 0): 33.06695556640625,
#   datetime.datetime(2023, 8, 29, 0, 0): 33.745601654052734,
#   datetime.datetime(2023, 8, 30, 0, 0): 33.96198272705078,
#   datetime.datetime(2023, 8, 31, 0, 0): 34.56195068359375,
#   datetime.datetime(2023, 9, 1, 0, 0): 36.00776672363281,
#   datetime.datetime(2023, 9, 5, 0, 0): 36.10612487792969,
#   datetime.datetime(2023, 9, 6, 0, 0): 36.37167739868164,
#   datetime.datetime(2023, 9, 7, 0, 0): 37.551944732666016,
#   datetime.datetime(2023, 9, 8, 0, 0): 37.38473892211914,
#   datetime.datetime(2023, 9, 11, 0, 0): 37.955196380615234,
#   datetime.datetime(2023, 9, 12, 0, 0): 38.22075271606445,
#   datetime.datetime(2023, 9, 13, 0, 0): 38.07322311401367,
#   datetime.datetime(2023, 9, 14, 0, 0): 38.033878326416016,
#   datetime.datetime(2023, 9, 15, 0, 0): 37.25687789916992,
#   datetime.datetime(2023, 9, 18, 0, 0): 37.36506652832031,
#   datetime.datetime(2023, 9, 19, 0, 0): 35.74220657348633,
#   datetime.datetime(2023, 9, 20, 0, 0): 34.11935043334961,
#   datetime.datetime(2023, 9, 21, 0, 0): 34.08000946044922,
#   datetime.datetime(2023, 9, 22, 0, 0): 33.61774063110352,
#   datetime.datetime(2023, 9, 25, 0, 0): 33.725929260253906,
#   datetime.datetime(2023, 9, 26, 0, 0): 33.27349853515625,
#   datetime.datetime(2023, 9, 27, 0, 0): 34.04066848754883,
#   datetime.datetime(2023, 9, 28, 0, 0): 34.601287841796875,
#   datetime.datetime(2023, 9, 29, 0, 0): 34.96520233154297,
#   datetime.datetime(2023, 10, 2, 0, 0): 34.87668228149414,
#   datetime.datetime(2023, 10, 3, 0, 0): 35.10289764404297,
#   datetime.datetime(2023, 10, 4, 0, 0): 35.33895492553711,
#   datetime.datetime(2023, 10, 5, 0, 0): 35.29960632324219,
#   datetime.datetime(2023, 10, 6, 0, 0): 35.59467315673828,
#   datetime.datetime(2023, 10, 9, 0, 0): 35.46681594848633,
#   datetime.datetime(2023, 10, 10, 0, 0): 35.83073043823242,
#   datetime.datetime(2023, 10, 11, 0, 0): 36.2733268737793,
#   datetime.datetime(2023, 10, 12, 0, 0): 36.233985900878906,
#   datetime.datetime(2023, 10, 13, 0, 0): 35.378292083740234,
#   datetime.datetime(2023, 10, 16, 0, 0): 35.95859146118164,
#   datetime.datetime(2023, 10, 17, 0, 0): 35.46681594848633,
#   datetime.datetime(2023, 10, 18, 0, 0): 35.0537223815918,
#   datetime.datetime(2023, 10, 19, 0, 0): 35.083229064941406,
#   datetime.datetime(2023, 10, 20, 0, 0): 34.3455696105957,
#   datetime.datetime(2023, 10, 23, 0, 0): 33.29317092895508,
#   datetime.datetime(2023, 10, 24, 0, 0): 34.02099609375,
#   datetime.datetime(2023, 10, 25, 0, 0): 32.289947509765625,
#   datetime.datetime(2023, 10, 26, 0, 0): 31.985050201416016,
#   datetime.datetime(2023, 10, 27, 0, 0): 34.95536804199219,
#   datetime.datetime(2023, 10, 30, 0, 0): 35.10289764404297,
#   datetime.datetime(2023, 10, 31, 0, 0): 35.89957427978516,
#   datetime.datetime(2023, 11, 1, 0, 0): 36.67658233642578,
#   datetime.datetime(2023, 11, 2, 0, 0): 37.079837799072266,
#   datetime.datetime(2023, 11, 3, 0, 0): 37.51259994506836,
#   datetime.datetime(2023, 11, 6, 0, 0): 37.448463439941406,
#   datetime.datetime(2023, 11, 7, 0, 0): 38.25762176513672,
#   datetime.datetime(2023, 11, 8, 0, 0): 37.418853759765625,
#   datetime.datetime(2023, 11, 9, 0, 0): 37.30044174194336,
#   datetime.datetime(2023, 11, 10, 0, 0): 38.34643173217773,
#   datetime.datetime(2023, 11, 13, 0, 0): 37.72475814819336,
#   datetime.datetime(2023, 11, 14, 0, 0): 38.88916778564453,
#   datetime.datetime(2023, 11, 15, 0, 0): 40.07330703735352,
#   datetime.datetime(2023, 11, 16, 0, 0): 42.7770881652832,
#   datetime.datetime(2023, 11, 17, 0, 0): 43.23101806640625,
#   datetime.datetime(2023, 11, 20, 0, 0): 44.14872741699219,
#   datetime.datetime(2023, 11, 21, 0, 0): 43.063262939453125,
#   datetime.datetime(2023, 11, 22, 0, 0): 43.09286117553711,
#   datetime.datetime(2023, 11, 24, 0, 0): 43.3790283203125,
#   datetime.datetime(2023, 11, 27, 0, 0): 43.4974479675293,
#   datetime.datetime(2023, 11, 28, 0, 0): 43.64546203613281,
#   datetime.datetime(2023, 11, 29, 0, 0): 44.34607696533203,
#   datetime.datetime(2023, 11, 30, 0, 0): 44.1092529296875,
#   datetime.datetime(2023, 12, 1, 0, 0): 43.16194152832031,
#   datetime.datetime(2023, 12, 4, 0, 0): 41.790306091308594,
#   datetime.datetime(2023, 12, 5, 0, 0): 41.365989685058594,
#   datetime.datetime(2023, 12, 6, 0, 0): 40.72458267211914,
#   datetime.datetime(2023, 12, 7, 0, 0): 41.59295654296875,
#   datetime.datetime(2023, 12, 8, 0, 0): 42.135684967041016,
#   datetime.datetime(2023, 12, 11, 0, 0): 43.95136642456055,
#   datetime.datetime(2023, 12, 12, 0, 0): 43.45797729492188,
#   datetime.datetime(2023, 12, 13, 0, 0): 43.9809684753418,
#   datetime.datetime(2023, 12, 14, 0, 0): 44.58290863037109,
#   datetime.datetime(2023, 12, 15, 0, 0): 45.54995346069336,
#   datetime.datetime(2023, 12, 18, 0, 0): 45.0861701965332,
#   datetime.datetime(2023, 12, 19, 0, 0): 46.0433464050293,
#   datetime.datetime(2023, 12, 20, 0, 0): 45.15524291992188,
#   ...}}

# %% [markdown]
# # 定义`Portfolio`类

# %% [markdown]
# 回忆我们之前的分析：
#
#     ...
#     2. 基于个股数据，便可以进行模拟交易。所谓构建Portfolio，本质上是追踪一系列股票交易行为。那么，如何存储交易数据？
#     3. 基于一个Portfolio的交易数据，可以计算该Portfolio在任意时间点的持仓数据。结合个股数据，便可以计算该Portfolio在该时间点的资产价值。
#     ...
#
# 思考：如何基于OOP的思想，实现上述需求？
#
# 请利用你从`Stock`类的实现中学到的知识，设计`Portfolio`类。具体而言，需实现如下功能。
#
# 1. 属性：
#     + 现金（`cash`）
#     + 持仓信息（`holdings`）
#     + 交易历史（`trade_history`）
#
# 2. 方法：
#     + 转入现金（`deposit_cash`）
#     + 买单支股票（`buy_stock`）
#     + 卖单支股票（`sell_stock`）
#     + 基于当前持仓，估计任意时间点**当前**持有资产的总价值（`get_value_c`）
#     + 回溯交易历史，估计任意时间点**历史**持有资产的总价值（`get_value_h`）
#
# 思考：`holdings`和`trade_history`该用什么数据结构存储？实现`buy_stock`和`sell_stock`时该注意哪些事项？实现`get_value_h`时，该如何使用`trade_history`中的信息？

# %% [markdown]
# 请阅读下方代码，学习并掌握以下几个知识点：
#
# + `buy_stock`的实现逻辑
# + `holding_stocks`的实现方法及意义
# + `get_averge_holding_cost`以及`__repr__`的实现细节

# %%
# Define the Portfolio class with buy and sell actions
class Portfolio:
    def __init__(self):
        self.cash = 0
        self.holdings = {} 
        self.trade_history = []

    def deposit_cash(self, amount):
        self.cash += amount

    def buy_stock(self, stock, quantity, date):
        price = stock.get_price(date)
        if price is None:
            raise ValueError(f"No price available for {stock.name} on {date}.")
        
        total_cost = price * quantity
        if total_cost >= self.cash:
            raise ValueError("Insufficient funds to buy stock.")
        
        self.cash -= total_cost
        if stock.name in self.holdings:
            self.holdings[stock.name]["quantity"] += quantity
        else:
            self.holdings[stock.name] = {"stock": stock, "quantity": quantity}
        self.trade_history.append(('buy', stock.name, quantity, date, price))
    
    @property
    def holding_stocks(self):
        return list(self.holdings.keys())
    
    def get_averge_holding_cost(self, stock_name, verbose=False):
        purchase_records = [
            # (quantity, price)
            (action[2], action[4]) for action in self.trade_history 
            if (action[0]=='buy') and (action[1]==stock_name)]
        total_value_p = sum([q*p for q, p in purchase_records])
        total_quant_p = sum([q for q, _ in purchase_records])

        sell_records = [
            # (quantity, price)
            (action[2], action[4]) for action in self.trade_history 
            if (action[0]=='sell') and (action[1]==stock_name)]
        total_value_s = sum([q*p for q, p in sell_records])
        total_quant_s = sum([q for q, _ in sell_records])
        
        total_value = total_value_p - total_value_s
        total_quant = total_quant_p - total_quant_s
        average_cost = total_value/total_quant
        
        if verbose:
            return average_cost, total_value, total_quant
        else:
            return average_cost
        
    def __repr__(self):
        cash_info = f"cash: {self.cash:.2f} | "
        stock_info = []
        for stock_name in self.holding_stocks:
            price, value, quant = self.get_averge_holding_cost(stock_name, verbose=True)
            stock_info.append(f"{stock_name}: {value:.2f}={quant}*{price:.2f}")
        stock_info = ' | '.join(stock_info)
        return cash_info + stock_info + " (cost information)"

# %% [markdown]
# 功能测试

# %%
portfolio = Portfolio()
portfolio.deposit_cash(1000)
stock_aapl = Stock.from_ticker('AAPL')
stock_msft = Stock.from_ticker('MSFT')
# portfolio.buy_stock(stock_aapl, 10, datetime.strptime('2023-1-1', '%Y-%m-%d'))
# portfolio.buy_stock(stock_aapl, 20, datetime.strptime('2023-1-5', '%Y-%m-%d'))
portfolio.buy_stock(stock_aapl, 5, stock_aapl.trading_dates[0])
portfolio.buy_stock(stock_msft, 2, stock_aapl.trading_dates[0])
portfolio
# Out:
# cash: 327.74 | AAPL: 364.38=5*72.88 | MSFT: 307.88=2*153.94 (cost information)

# %%
portfolio.trade_history
# Out:
# [('buy', 'AAPL', 5, datetime.datetime(2020, 1, 2, 0, 0), 72.87610626220703),
#  ('buy', 'MSFT', 2, datetime.datetime(2020, 1, 2, 0, 0), 153.93821716308594)]

# %% [markdown]
# 进一步完善`Stock`类。

# %%
# Define the Portfolio class with buy and sell actions
class Portfolio:
    def __init__(self):
        self.cash = 0
        self.holdings = {} 
        self.trade_history = []

    def deposit_cash(self, amount):
        self.cash += amount

    def buy_stock(self, stock, quantity, date):
        price = stock.get_price(date)
        if price is None:
            raise ValueError(f"No price available for {stock.name} on {date}.")
        
        total_cost = price * quantity
        if total_cost >= self.cash:
            raise ValueError("Insufficient funds to buy stock.")
        
        self.cash -= total_cost
        if stock.name in self.holdings:
            self.holdings[stock.name]["quantity"] += quantity
        else:
            self.holdings[stock.name] = {"stock": stock, "quantity": quantity}
        self.trade_history.append(('buy', stock.name, quantity, date, price))

    def sell_stock(self, stock, quantity, date):
        if stock.ticker not in self.holdings or self.holdings[stock.name]["quantity"] < quantity:
            raise ValueError("Insufficient stock quantity to sell.")
        
        price = stock.get_price(date)
        if price is None:
            raise ValueError(f"No price available for {stock.name} on {date}.")
        
        proceeds = price * quantity
        self.cash += proceeds
        self.holdings[stock.name]["quantity"] -= quantity
        if self.holdings[stock.name]["quantity"] == 0:
            del self.holdings[stock.name]
        self.trade_history.append(('sell', stock.name, quantity, date, price))
    
    def get_value_c(self, date):
        # Calculate total value of the portfolio on a specific date, using the most recent trading date if necessary
        total_value = self.cash
        for holding in self.holdings.values():
            stock = holding["stock"]
            quantity = holding["quantity"]
            
            # Attempt to get the stock price for the requested date
            stock_price = stock.get_price(date)
            
            # If no price available, use the most recent available trading date's price
            if stock_price is None:
                past_trading_dates = [d for d in stock.trading_dates if d <= date]
                if past_trading_dates:
                    most_recent_date = max(past_trading_dates)
                    stock_price = stock.get_price(most_recent_date)
            # Add value to total if a price is found
            if stock_price:
                total_value += stock_price * quantity
                
        return total_value
    
    @property
    def holding_stocks(self):
        return list(self.holdings.keys())
    
    def get_averge_holding_cost(self, stock_name, verbose=False):
        purchase_records = [
            # (quantity, price)
            (action[2], action[4]) for action in self.trade_history 
            if (action[0]=='buy') and (action[1]==stock_name)]
        total_value_p = sum([q*p for q, p in purchase_records])
        total_quant_p = sum([q for q, _ in purchase_records])

        sell_records = [
            # (quantity, price)
            (action[2], action[4]) for action in self.trade_history 
            if (action[0]=='sell') and (action[1]==stock_name)]
        total_value_s = sum([q*p for q, p in sell_records])
        total_quant_s = sum([q for q, _ in sell_records])
        
        total_value = total_value_p - total_value_s
        total_quant = total_quant_p - total_quant_s
        average_cost = total_value/total_quant
        
        if verbose:
            return average_cost, total_value, total_quant
        else:
            return average_cost
        
    def __repr__(self):
        cash_info = f"cash: {self.cash:.2f} | "
        stock_info = []
        for stock_name in self.holding_stocks:
            price, value, quant = self.get_averge_holding_cost(stock_name, verbose=True)
            stock_info.append(f"{stock_name}: {value:.2f}={quant}*{price:.2f}")
        stock_info = ' | '.join(stock_info)
        return cash_info + stock_info + " (cost information)"

# %% [markdown]
# 功能测试

# %%
portfolio = Portfolio()
portfolio.deposit_cash(1000)
stock_aapl = Stock.from_ticker('AAPL')
stock_msft = Stock.from_ticker('MSFT')
portfolio.buy_stock(stock_aapl, 5, stock_aapl.trading_dates[0])
portfolio.buy_stock(stock_msft, 2, stock_aapl.trading_dates[0])
portfolio.sell_stock(stock_aapl, 4, stock_aapl.trading_dates[1])
portfolio.sell_stock(stock_msft, 1, stock_aapl.trading_dates[1])
portfolio.get_value_c(stock_aapl.trading_dates[-1])
# Out:
# 1431.0647659301758

# %%
portfolio.trade_history
# Out:
# [('buy', 'AAPL', 5, datetime.datetime(2020, 1, 2, 0, 0), 72.87610626220703),
#  ('buy', 'MSFT', 2, datetime.datetime(2020, 1, 2, 0, 0), 153.93821716308594),
#  ('sell', 'AAPL', 4, datetime.datetime(2020, 1, 3, 0, 0), 72.16758728027344),
#  ('sell', 'MSFT', 1, datetime.datetime(2020, 1, 3, 0, 0), 152.02137756347656)]

# %% [markdown]
# # 实现交易策略

# %%
# Assuming Stock and Portfolio classes are already defined as before
# Only the TSTrendFollow class logic has been updated

class TSTrendFollow:
    def __init__(self, lookback_days=5):
        self.portfolio = Portfolio()
        self.lookback_days = lookback_days

    def __call__(self, stock_pool, investment_amount, start_date, end_date, reset=False):
        if reset:
            self.portfolio = Portfolio()
        # Deposit initial investment
        self.portfolio.deposit_cash(investment_amount)

        # Generate list of all trading dates across the stock pool
        all_dates = sorted(set(date for stock in stock_pool for date in stock.trading_dates))
        trading_dates = [date for date in all_dates if start_date <= date <= end_date]

        for date in trading_dates:
            tradable_stocks = []

            # Check each stock for tradability and trend-following criteria
            for stock in stock_pool:
                # Ensure the stock has a price on the given date
                current_price = stock.get_price(date)
                if current_price is None:
                    continue

                # Calculate moving average for the past lookback_days trading dates
                past_dates = [d for d in stock.trading_dates if d < date][-self.lookback_days:]
                past_prices = [stock.get_price(d) for d in past_dates if stock.get_price(d) is not None]

                # Only consider if we have enough past data
                if len(past_prices) == self.lookback_days:
                    moving_average = np.mean(past_prices)

                    # Determine if the stock satisfies buy/sell condition
                    if current_price > moving_average:
                        tradable_stocks.append((stock, current_price, "buy"))
                    elif current_price < moving_average and stock.ticker in self.portfolio.holdings:
                        tradable_stocks.append((stock, current_price, "sell"))

            # Allocate budget proportionally among stocks that satisfy buy criteria
            if tradable_stocks:
                buy_stocks = [s for s in tradable_stocks if s[2] == "buy"]
                sell_stocks = [s for s in tradable_stocks if s[2] == "sell"]

                # Calculate budget share based on relative performance for buy stocks
                if buy_stocks:
                    total_performance = sum(s[1] for s in buy_stocks)
                    for stock, current_price, _ in buy_stocks:
                        allocation_ratio = current_price / total_performance
                        available_cash = self.portfolio.cash * allocation_ratio
                        quantity = available_cash // current_price
                        if quantity > 0:
                            self.portfolio.buy_stock(stock, quantity, date)

                # Execute sales for stocks that meet the sell condition
                for stock, current_price, _ in sell_stocks:
                    quantity = self.portfolio.holdings[stock.ticker]["quantity"]
                    self.portfolio.sell_stock(stock, quantity, date)

        # Return the final portfolio value at the end date
        return self.portfolio.get_value_c(end_date)

# %%
trend_follow_strategy = TSTrendFollow()

# %%
# Initialize stock instances
pools_1 = ["AAPL", "MSFT", "GOOGL"]
stocks = [Stock(symbol, symbol, stock_data[symbol]) for symbol in pools_1]

# Run the trend-following strategy
investment_amount = 10000
strategy_start_date = datetime.strptime("2023-01-01", "%Y-%m-%d")
strategy_end_date = datetime.strptime("2023-12-31", "%Y-%m-%d")
n_days = (strategy_end_date - strategy_start_date).days + 1

final_value = trend_follow_strategy(stocks, investment_amount, strategy_start_date, strategy_end_date)
print(f"Final Portfolio Value: ${final_value:.2f}")

# Plotting portfolio performance
portfolio_values = []
dates = [strategy_start_date+timedelta(days=i) for i in range(n_days)]
for date in dates:
    portfolio_values.append(trend_follow_strategy.portfolio.get_value_c(date))

plt.figure(figsize=(10, 6))
plt.plot(dates, portfolio_values, label="Portfolio Value")
plt.xlabel("Date")
plt.ylabel("Portfolio Value ($)")
plt.title("Trend-Following Strategy Portfolio Performance")
plt.legend()
plt.show()
# Out:
# Final Portfolio Value: $12654.89

# %%
pd.DataFrame(trend_follow_strategy.portfolio.trade_history)
# Out:
#         0      1     2          3           4
# 0     buy   MSFT  30.0 2023-01-03  236.183533
# 1     buy  GOOGL   8.0 2023-01-03   88.899872
# 2     buy  GOOGL  25.0 2023-01-04   87.862442
# 3    sell   MSFT  30.0 2023-01-04  225.852112
# 4    sell  GOOGL  33.0 2023-01-05   85.987076
# ..    ...    ...   ...        ...         ...
# 211   buy   MSFT   3.0 2023-12-22  372.543915
# 212   buy  GOOGL   1.0 2023-12-22  141.140518
# 213   buy   MSFT   1.0 2023-12-26  372.623505
# 214  sell  GOOGL  38.0 2023-12-28  139.883621
# 215   buy   MSFT  14.0 2023-12-29  373.996002
#
# [216 rows x 5 columns]

# %% [markdown]
# 为什么下面的直线是平的？

# %%
# Initialize stock instances
pools_2 = ["BA", "WBA"]
stocks = [Stock(symbol, symbol, stock_data[symbol]) for symbol in pools_2]

# Run the trend-following strategy
final_value = trend_follow_strategy(stocks, investment_amount, strategy_start_date, strategy_end_date, reset=True)
print(f"Final Portfolio Value: ${final_value:.2f}")

# Plotting portfolio performance
portfolio_values = []
for date in dates:
    portfolio_values.append(trend_follow_strategy.portfolio.get_value_c(date))

plt.figure(figsize=(10, 6))
plt.plot(dates, portfolio_values, label="Portfolio Value")
plt.xlabel("Date")
plt.ylabel("Portfolio Value ($)")
plt.title("Trend-Following Strategy Portfolio Performance")
plt.legend()
plt.show()
# Out:
# Final Portfolio Value: $9664.70

# %%
pd.DataFrame(trend_follow_strategy.portfolio.trade_history)
# Out:
#         0    1     2          3           4
# 0     buy   BA  51.0 2023-01-03  195.389999
# 1    sell   BA  51.0 2023-01-18  209.410004
# 2     buy   BA  44.0 2023-01-23  209.970001
# 3     buy  WBA   6.0 2023-01-23   32.583054
# 4     buy   BA   6.0 2023-01-24  211.979996
# ..    ...  ...   ...        ...         ...
# 110   buy  WBA   3.0 2023-12-26   25.345119
# 111   buy   BA   3.0 2023-12-27  262.100006
# 112   buy  WBA   4.0 2023-12-28   25.335598
# 113  sell   BA  36.0 2023-12-28  260.350006
# 114  sell  WBA  11.0 2023-12-29   24.868887
#
# [115 rows x 5 columns]

# %%
trend_follow_strategy.portfolio
# Out:
# cash: 9664.70 |  (cost information)
